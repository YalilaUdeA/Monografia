# %% [markdown]
# # Flower Classification
#
# **Exploracion de datos y Preprocesamiento**
#
# **Yalila Aljure Jimenez**
#
# email: yalila.aljure@udea.edu.co
#
# CC. 5288540

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.6.0'

# %%
import keras
keras.__version__
# Out:
# '2.6.0'

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import PIL
import pathlib
from mpl_toolkits.axes_grid1 import ImageGrid
from matplotlib import pyplot as plt
import random
import math 
from sklearn.metrics import roc_curve, auc, multilabel_confusion_matrix, plot_confusion_matrix, roc_auc_score
from keras.layers import Conv2D, Dropout, MaxPooling2D, BatchNormalization, Activation, Flatten, Dense, InputLayer, Input
from keras.models import Sequential, Model
import mlflow
import mlflow.keras
import cv2

# %% [markdown]
# **LOAD DATA**

# %%
# !wget https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# Out:
# --2021-09-18 22:58:16--  https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.112.128, 74.125.124.128, 172.217.212.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.112.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 228813984 (218M) [application/x-compressed-tar]
# Saving to: ‘flower_photos.tgz’
#
# flower_photos.tgz   100%[===================>] 218.21M   169MB/s    in 1.3s
#
# 2021-09-18 22:58:17 (169 MB/s) - ‘flower_photos.tgz’ saved [228813984/228813984]

# %%
# Unzipping Data
# !gunzip flower_photos.tgz

# %%
# !tar -xvf flower_photos.tar

# %% [markdown]
# **Plotting Images**

# %%
data_dir = pathlib.Path('flower_photos')
folder = list(data_dir.glob('*'))
images = list(data_dir.glob('*/*.jpg')) #list of all images (full path)

# %%
len(images) # Number of images
# Out:
# 3670

# %%
fig = plt.figure(figsize=(20, 20))
iterable = np.array(random.sample(range(1, 3670), 54)) # Choosing 54 random images
for i in range(54):
    plt.subplot(9, 6, i+1)
    j = iterable[i]
    plt.title(str(images[j]).split('/')[-1], fontsize=10) # file name and disply as title
    plt.imshow(PIL.Image.open(images[j])) # Displaying Image
    ax = plt.axis("off")

# %% [markdown]
# **Parameters**

# %%
image_size = 224 # Setting the size of the images
b_size = 32

# %% [markdown]
# **Imagen Preprocessing**
#
# Data Augmantation

# %% [markdown]
# Original source is not partitioned. The test set will be fixed at 20% of the entire dataset. The rest of the dataset will be used for training (0.8) and validation (0.2).

# %%
idg_flip = tf.keras.preprocessing.image.ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest',
    validation_split = 0.2
)

# %%
flower_gen_train = idg_flip.flow_from_directory(data_dir,
                                    target_size=(image_size, image_size),
                                    batch_size=b_size,
                                    subset='training',
                                    class_mode='categorical',
                                    shuffle=True,
                                    seed=123
                                    )
# Out:
# Found 2939 images belonging to 5 classes.

# %%
flower_gen_test = idg_flip.flow_from_directory(data_dir,
                                    target_size=(image_size, image_size),
                                    batch_size=b_size,
                                    subset='validation',
                                    class_mode='categorical',
                                    shuffle=True,
                                    seed=123
                                    )
# Out:
# Found 731 images belonging to 5 classes.

# %% [markdown]
# **VGGNet**

# %%
# Instanciate and empty model
model = Sequential()
# First Convolutional Layer
model.add(Conv2D(64, kernel_size=(3,3), activation='swish',padding='same',input_shape=(image_size,image_size,3))) # 2D Convolution layer, filters = 64
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(64, kernel_size=(3,3), activation='swish',padding='same')) # 2D Convolution layer, filters = 64
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(BatchNormalization()) 
# Second Convolutional Layer
model.add(Conv2D(128, kernel_size=(3,3), activation='swish', padding='same')) # 2D Convolution layer, filters = 128
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(128, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 128
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(BatchNormalization()) 
# Third Convolutional Layer
model.add(Conv2D(256, kernel_size=(3,3), activation='swish',padding='same')) # 2D Convolution layer, filters = 256
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(256, kernel_size=(3,3), activation='swish',padding='same')) # 2D Convolution layer, filters = 256
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(256, kernel_size=(3,3), activation='swish',padding='same')) # 2D Convolution layer, filters = 256
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(BatchNormalization()) 
# Fourth Convolutional Layer
model.add(Conv2D(512, kernel_size=(3,3), activation='swish',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='swish',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='swish',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(BatchNormalization()) 
# Fith convolutional layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='swish',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='swish',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='swish',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(BatchNormalization()) 
# 1st dense layer
model.add(Flatten()) 
model.add(Dense(4096))
# Dropout
model.add(Dropout(0.5)) 
model.add(Activation('swish'))
# 2nd Dense Layer
model.add(Dense(4096))
# Dropout
model.add(Dropout(0.5))
# Normalization
model.add(BatchNormalization()) 
model.add(Activation('swish'))
# Output softmax layer
model.add(Dense(5))
model.add(Activation('softmax'))

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy','Precision','Recall'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 56, 56, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 128)       247936
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 256)       295168
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 256)         590080
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1, 1, 256)         1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 1, 512)         1180160
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 1, 1, 512)         2359808
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 1, 1, 512)         2359808
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1, 1, 512)         2048
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 1, 1, 512)         2359808
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 1, 1, 512)         2359808
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 1, 1, 512)         2359808
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1, 1, 512)         2048
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# activation (Activation)      (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4096)              16384
# _________________________________________________________________
# activation_1 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 20485
# _________________________________________________________________
# activation_2 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 33,740,357
# Trainable params: 33,729,221
# Non-trainable params: 11,136
# _________________________________________________________________

# %%
Result = model.fit(flower_gen_train, validation_data=flower_gen_test
                   , epochs=100, verbose=1, shuffle=True)
# Out:
# 2021/09/18 22:58:52 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '903d668e4cb44e539247832fa5d0f377', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current keras workflow
# Epoch 1/100
# 92/92 [==============================] - 95s 649ms/step - loss: 1.2119 - accuracy: 0.5009 - precision: 0.6209 - recall: 0.2953 - val_loss: 1.6090 - val_accuracy: 0.2175 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 92/92 [==============================] - 58s 629ms/step - loss: 1.0383 - accuracy: 0.5920 - precision: 0.6914 - recall: 0.4590 - val_loss: 1.6090 - val_accuracy: 0.2175 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 92/92 [==============================] - 57s 624ms/step - loss: 0.9478 - accuracy: 0.6349 - precision: 0.7165 - recall: 0.5202 - val_loss: 1.6086 - val_accuracy: 0.2175 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/100
# 92/92 [==============================] - 57s 622ms/step - loss: 0.8961 - accuracy: 0.6512 - precision: 0.7258 - recall: 0.5495 - val_loss: 1.6063 - val_accuracy: 0.3228 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/100
# 92/92 [==============================] - 57s 621ms/step - loss: 0.8425 - accuracy: 0.6652 - precision: 0.7407 - recall: 0.5869 - val_loss: 1.5873 - val_accuracy: 0.3201 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/100
# 92/92 [==============================] - 57s 618ms/step - loss: 0.8516 - accuracy: 0.6730 - precision: 0.7435 - recall: 0.5869 - val_loss: 1.4870 - val_accuracy: 0.5363 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/100
# 92/92 [==============================] - 57s 622ms/step - loss: 0.8255 - accuracy: 0.6829 - precision: 0.7514 - recall: 0.5995 - val_loss: 1.2375 - val_accuracy: 0.5923 - val_precision: 0.7959 - val_recall: 0.1067
# Epoch 8/100
# 92/92 [==============================] - 59s 644ms/step - loss: 0.7863 - accuracy: 0.6999 - precision: 0.7719 - recall: 0.6216 - val_loss: 1.0070 - val_accuracy: 0.6238 - val_precision: 0.7948 - val_recall: 0.3762
# Epoch 9/100
# 92/92 [==============================] - 58s 628ms/step - loss: 0.7805 - accuracy: 0.7036 - precision: 0.7784 - recall: 0.6312 - val_loss: 0.8479 - val_accuracy: 0.6717 - val_precision: 0.7717 - val_recall: 0.5363
# Epoch 10/100
# 92/92 [==============================] - 57s 621ms/step - loss: 0.7425 - accuracy: 0.7132 - precision: 0.7820 - recall: 0.6482 - val_loss: 0.7956 - val_accuracy: 0.6799 - val_precision: 0.7669 - val_recall: 0.5896
# Epoch 11/100
# 92/92 [==============================] - 57s 618ms/step - loss: 0.7210 - accuracy: 0.7162 - precision: 0.7824 - recall: 0.6523 - val_loss: 0.9035 - val_accuracy: 0.6840 - val_precision: 0.7474 - val_recall: 0.5910
# Epoch 12/100
# 92/92 [==============================] - 57s 618ms/step - loss: 0.7092 - accuracy: 0.7309 - precision: 0.7917 - recall: 0.6649 - val_loss: 0.8026 - val_accuracy: 0.7004 - val_precision: 0.7662 - val_recall: 0.6320
# Epoch 13/100
# 92/92 [==============================] - 57s 620ms/step - loss: 0.7075 - accuracy: 0.7278 - precision: 0.7939 - recall: 0.6645 - val_loss: 0.8205 - val_accuracy: 0.7004 - val_precision: 0.7585 - val_recall: 0.6443
# Epoch 14/100
# 92/92 [==============================] - 58s 630ms/step - loss: 0.6643 - accuracy: 0.7414 - precision: 0.8030 - recall: 0.6849 - val_loss: 1.1637 - val_accuracy: 0.5773 - val_precision: 0.6610 - val_recall: 0.5280
# Epoch 15/100
# 92/92 [==============================] - 59s 637ms/step - loss: 0.6746 - accuracy: 0.7370 - precision: 0.8017 - recall: 0.6754 - val_loss: 0.9665 - val_accuracy: 0.6443 - val_precision: 0.7190 - val_recall: 0.5705
# Epoch 16/100
# 92/92 [==============================] - 59s 644ms/step - loss: 0.6759 - accuracy: 0.7421 - precision: 0.7978 - recall: 0.6846 - val_loss: 0.8267 - val_accuracy: 0.6607 - val_precision: 0.7513 - val_recall: 0.6115
# Epoch 17/100
# 92/92 [==============================] - 59s 641ms/step - loss: 0.6709 - accuracy: 0.7455 - precision: 0.8053 - recall: 0.6798 - val_loss: 1.3647 - val_accuracy: 0.6443 - val_precision: 0.6741 - val_recall: 0.6197
# Epoch 18/100
# 92/92 [==============================] - 57s 622ms/step - loss: 0.6568 - accuracy: 0.7431 - precision: 0.7988 - recall: 0.6808 - val_loss: 1.0685 - val_accuracy: 0.6662 - val_precision: 0.6970 - val_recall: 0.6293
# Epoch 19/100
# 92/92 [==============================] - 58s 625ms/step - loss: 0.6232 - accuracy: 0.7618 - precision: 0.8152 - recall: 0.7115 - val_loss: 0.8214 - val_accuracy: 0.7045 - val_precision: 0.7458 - val_recall: 0.6621
# Epoch 20/100
# 92/92 [==============================] - 57s 623ms/step - loss: 0.6054 - accuracy: 0.7666 - precision: 0.8214 - recall: 0.7183 - val_loss: 1.1685 - val_accuracy: 0.6416 - val_precision: 0.6787 - val_recall: 0.5923
# Epoch 21/100
# 92/92 [==============================] - 58s 631ms/step - loss: 0.6057 - accuracy: 0.7703 - precision: 0.8253 - recall: 0.7247 - val_loss: 0.9009 - val_accuracy: 0.7073 - val_precision: 0.7389 - val_recall: 0.6854
# Epoch 22/100
# 92/92 [==============================] - 59s 637ms/step - loss: 0.5864 - accuracy: 0.7775 - precision: 0.8199 - recall: 0.7329 - val_loss: 0.9360 - val_accuracy: 0.6689 - val_precision: 0.7159 - val_recall: 0.6170
# Epoch 23/100
# 92/92 [==============================] - 58s 631ms/step - loss: 0.5877 - accuracy: 0.7741 - precision: 0.8271 - recall: 0.7292 - val_loss: 0.7611 - val_accuracy: 0.7332 - val_precision: 0.7795 - val_recall: 0.6867
# Epoch 24/100
# 92/92 [==============================] - 58s 632ms/step - loss: 0.5873 - accuracy: 0.7795 - precision: 0.8197 - recall: 0.7315 - val_loss: 1.1504 - val_accuracy: 0.6375 - val_precision: 0.6756 - val_recall: 0.5869
# Epoch 25/100
# 92/92 [==============================] - 58s 626ms/step - loss: 0.5713 - accuracy: 0.7761 - precision: 0.8264 - recall: 0.7258 - val_loss: 1.0962 - val_accuracy: 0.6867 - val_precision: 0.7239 - val_recall: 0.6635
# Epoch 26/100
# 92/92 [==============================] - 59s 640ms/step - loss: 0.5643 - accuracy: 0.7873 - precision: 0.8377 - recall: 0.7411 - val_loss: 0.6705 - val_accuracy: 0.7538 - val_precision: 0.8190 - val_recall: 0.7059
# Epoch 27/100
# 92/92 [==============================] - 58s 629ms/step - loss: 0.5430 - accuracy: 0.7945 - precision: 0.8437 - recall: 0.7547 - val_loss: 0.7861 - val_accuracy: 0.7387 - val_precision: 0.7862 - val_recall: 0.6990
# Epoch 28/100
# 92/92 [==============================] - 58s 630ms/step - loss: 0.5263 - accuracy: 0.7989 - precision: 0.8426 - recall: 0.7560 - val_loss: 0.7639 - val_accuracy: 0.7401 - val_precision: 0.7749 - val_recall: 0.6922
# Epoch 29/100
# 92/92 [==============================] - 58s 629ms/step - loss: 0.5371 - accuracy: 0.7938 - precision: 0.8417 - recall: 0.7560 - val_loss: 1.0158 - val_accuracy: 0.6936 - val_precision: 0.7258 - val_recall: 0.6662
# Epoch 30/100
# 92/92 [==============================] - 58s 625ms/step - loss: 0.5027 - accuracy: 0.8067 - precision: 0.8453 - recall: 0.7696 - val_loss: 0.7928 - val_accuracy: 0.7250 - val_precision: 0.7811 - val_recall: 0.6785
# Epoch 31/100
# 92/92 [==============================] - 58s 628ms/step - loss: 0.5110 - accuracy: 0.8088 - precision: 0.8504 - recall: 0.7720 - val_loss: 0.8846 - val_accuracy: 0.7031 - val_precision: 0.7371 - val_recall: 0.6635
# Epoch 32/100
# 92/92 [==============================] - 58s 631ms/step - loss: 0.5254 - accuracy: 0.8020 - precision: 0.8431 - recall: 0.7605 - val_loss: 0.8081 - val_accuracy: 0.7291 - val_precision: 0.7608 - val_recall: 0.7004
# Epoch 33/100
# 92/92 [==============================] - 59s 638ms/step - loss: 0.4746 - accuracy: 0.8112 - precision: 0.8578 - recall: 0.7778 - val_loss: 0.9149 - val_accuracy: 0.7114 - val_precision: 0.7427 - val_recall: 0.6949
# Epoch 34/100
# 92/92 [==============================] - 58s 632ms/step - loss: 0.4691 - accuracy: 0.8234 - precision: 0.8623 - recall: 0.7904 - val_loss: 0.9093 - val_accuracy: 0.7209 - val_precision: 0.7562 - val_recall: 0.6703
# Epoch 35/100
# 92/92 [==============================] - 58s 626ms/step - loss: 0.4734 - accuracy: 0.8200 - precision: 0.8527 - recall: 0.7856 - val_loss: 0.7896 - val_accuracy: 0.7346 - val_precision: 0.7799 - val_recall: 0.6785
# Epoch 36/100
# 92/92 [==============================] - 57s 619ms/step - loss: 0.4798 - accuracy: 0.8149 - precision: 0.8500 - recall: 0.7826 - val_loss: 0.9470 - val_accuracy: 0.7237 - val_precision: 0.7644 - val_recall: 0.6881
# Epoch 37/100
# 92/92 [==============================] - 57s 614ms/step - loss: 0.4861 - accuracy: 0.8166 - precision: 0.8516 - recall: 0.7829 - val_loss: 0.7937 - val_accuracy: 0.7524 - val_precision: 0.7827 - val_recall: 0.7196
# Epoch 38/100
# 92/92 [==============================] - 57s 618ms/step - loss: 0.4756 - accuracy: 0.8289 - precision: 0.8618 - recall: 0.7935 - val_loss: 0.9069 - val_accuracy: 0.7086 - val_precision: 0.7314 - val_recall: 0.6854
# Epoch 39/100
# 92/92 [==============================] - 58s 630ms/step - loss: 0.4547 - accuracy: 0.8231 - precision: 0.8554 - recall: 0.7890 - val_loss: 0.8979 - val_accuracy: 0.7332 - val_precision: 0.7606 - val_recall: 0.7086
# Epoch 40/100
# 92/92 [==============================] - 58s 625ms/step - loss: 0.4565 - accuracy: 0.8268 - precision: 0.8612 - recall: 0.7962 - val_loss: 0.7487 - val_accuracy: 0.7319 - val_precision: 0.7812 - val_recall: 0.7031
# Epoch 41/100
# 92/92 [==============================] - 56s 605ms/step - loss: 0.4545 - accuracy: 0.8295 - precision: 0.8607 - recall: 0.8013 - val_loss: 0.7176 - val_accuracy: 0.7401 - val_precision: 0.7802 - val_recall: 0.6895
# Epoch 42/100
# 92/92 [==============================] - 56s 607ms/step - loss: 0.4360 - accuracy: 0.8377 - precision: 0.8673 - recall: 0.8091 - val_loss: 0.7712 - val_accuracy: 0.7497 - val_precision: 0.7904 - val_recall: 0.7223
# Epoch 43/100
# 92/92 [==============================] - 57s 616ms/step - loss: 0.4166 - accuracy: 0.8387 - precision: 0.8748 - recall: 0.8105 - val_loss: 0.9346 - val_accuracy: 0.7360 - val_precision: 0.7620 - val_recall: 0.7182
# Epoch 44/100
# 92/92 [==============================] - 57s 617ms/step - loss: 0.4474 - accuracy: 0.8329 - precision: 0.8677 - recall: 0.7969 - val_loss: 0.9010 - val_accuracy: 0.7305 - val_precision: 0.7533 - val_recall: 0.7100
# Epoch 45/100
# 92/92 [==============================] - 57s 617ms/step - loss: 0.3905 - accuracy: 0.8428 - precision: 0.8761 - recall: 0.8135 - val_loss: 0.8157 - val_accuracy: 0.7565 - val_precision: 0.7857 - val_recall: 0.7073
# Epoch 46/100
# 92/92 [==============================] - 57s 620ms/step - loss: 0.4093 - accuracy: 0.8459 - precision: 0.8728 - recall: 0.8220 - val_loss: 0.8749 - val_accuracy: 0.7155 - val_precision: 0.7511 - val_recall: 0.6936
# Epoch 47/100
# 92/92 [==============================] - 58s 632ms/step - loss: 0.4209 - accuracy: 0.8431 - precision: 0.8699 - recall: 0.8166 - val_loss: 0.7717 - val_accuracy: 0.7483 - val_precision: 0.7752 - val_recall: 0.7264
# Epoch 48/100
# 92/92 [==============================] - 58s 630ms/step - loss: 0.3817 - accuracy: 0.8520 - precision: 0.8793 - recall: 0.8251 - val_loss: 0.8531 - val_accuracy: 0.7401 - val_precision: 0.7754 - val_recall: 0.7319
# Epoch 49/100
# 92/92 [==============================] - 58s 633ms/step - loss: 0.4098 - accuracy: 0.8448 - precision: 0.8724 - recall: 0.8214 - val_loss: 0.7620 - val_accuracy: 0.7606 - val_precision: 0.7899 - val_recall: 0.7510
# Epoch 50/100
# 92/92 [==============================] - 58s 629ms/step - loss: 0.3875 - accuracy: 0.8510 - precision: 0.8721 - recall: 0.8258 - val_loss: 1.0338 - val_accuracy: 0.7209 - val_precision: 0.7378 - val_recall: 0.7045
# Epoch 51/100
# 92/92 [==============================] - 58s 630ms/step - loss: 0.3872 - accuracy: 0.8530 - precision: 0.8778 - recall: 0.8312 - val_loss: 0.7820 - val_accuracy: 0.7825 - val_precision: 0.8032 - val_recall: 0.7538
# Epoch 52/100
# 92/92 [==============================] - 58s 631ms/step - loss: 0.3587 - accuracy: 0.8642 - precision: 0.8844 - recall: 0.8435 - val_loss: 0.8705 - val_accuracy: 0.7551 - val_precision: 0.7762 - val_recall: 0.7401
# Epoch 53/100
# 92/92 [==============================] - 58s 629ms/step - loss: 0.3701 - accuracy: 0.8591 - precision: 0.8827 - recall: 0.8374 - val_loss: 0.6460 - val_accuracy: 0.7866 - val_precision: 0.8137 - val_recall: 0.7647
# Epoch 54/100
# 92/92 [==============================] - 58s 628ms/step - loss: 0.3732 - accuracy: 0.8578 - precision: 0.8807 - recall: 0.8418 - val_loss: 0.7748 - val_accuracy: 0.7373 - val_precision: 0.7651 - val_recall: 0.7086
# Epoch 55/100
# 92/92 [==============================] - 58s 631ms/step - loss: 0.3696 - accuracy: 0.8646 - precision: 0.8904 - recall: 0.8455 - val_loss: 0.8222 - val_accuracy: 0.7551 - val_precision: 0.7775 - val_recall: 0.7360
# Epoch 56/100
# 92/92 [==============================] - 58s 628ms/step - loss: 0.3602 - accuracy: 0.8663 - precision: 0.8851 - recall: 0.8465 - val_loss: 0.8109 - val_accuracy: 0.7373 - val_precision: 0.7586 - val_recall: 0.7264
# Epoch 57/100
# 92/92 [==============================] - 58s 629ms/step - loss: 0.3346 - accuracy: 0.8751 - precision: 0.8965 - recall: 0.8517 - val_loss: 0.9177 - val_accuracy: 0.7633 - val_precision: 0.7811 - val_recall: 0.7469
# Epoch 58/100
# 92/92 [==============================] - 58s 627ms/step - loss: 0.3530 - accuracy: 0.8724 - precision: 0.8963 - recall: 0.8527 - val_loss: 0.7344 - val_accuracy: 0.7647 - val_precision: 0.7867 - val_recall: 0.7469
# Epoch 59/100
# 92/92 [==============================] - 58s 629ms/step - loss: 0.3511 - accuracy: 0.8612 - precision: 0.8826 - recall: 0.8387 - val_loss: 0.7039 - val_accuracy: 0.7729 - val_precision: 0.8012 - val_recall: 0.7497
# Epoch 60/100
# 92/92 [==============================] - 58s 631ms/step - loss: 0.3343 - accuracy: 0.8724 - precision: 0.8929 - recall: 0.8537 - val_loss: 0.7533 - val_accuracy: 0.7565 - val_precision: 0.7847 - val_recall: 0.7278
# Epoch 61/100
# 92/92 [==============================] - 58s 629ms/step - loss: 0.3344 - accuracy: 0.8744 - precision: 0.8913 - recall: 0.8564 - val_loss: 0.8042 - val_accuracy: 0.7579 - val_precision: 0.7906 - val_recall: 0.7387
# Epoch 62/100
# 92/92 [==============================] - 58s 633ms/step - loss: 0.3211 - accuracy: 0.8755 - precision: 0.8968 - recall: 0.8571 - val_loss: 0.6545 - val_accuracy: 0.7893 - val_precision: 0.8103 - val_recall: 0.7715
# Epoch 63/100
# 92/92 [==============================] - 58s 628ms/step - loss: 0.3156 - accuracy: 0.8816 - precision: 0.9023 - recall: 0.8676 - val_loss: 0.7685 - val_accuracy: 0.7633 - val_precision: 0.7934 - val_recall: 0.7510
# Epoch 64/100
# 92/92 [==============================] - 58s 627ms/step - loss: 0.3289 - accuracy: 0.8782 - precision: 0.8953 - recall: 0.8646 - val_loss: 0.7707 - val_accuracy: 0.7715 - val_precision: 0.7937 - val_recall: 0.7524
# Epoch 65/100
# 92/92 [==============================] - 57s 623ms/step - loss: 0.3190 - accuracy: 0.8816 - precision: 0.9022 - recall: 0.8663 - val_loss: 0.7812 - val_accuracy: 0.7579 - val_precision: 0.7781 - val_recall: 0.7483
# Epoch 66/100
# 92/92 [==============================] - 57s 621ms/step - loss: 0.3186 - accuracy: 0.8833 - precision: 0.8973 - recall: 0.8680 - val_loss: 0.7568 - val_accuracy: 0.7633 - val_precision: 0.7853 - val_recall: 0.7305
# Epoch 67/100
# 92/92 [==============================] - 57s 618ms/step - loss: 0.3300 - accuracy: 0.8734 - precision: 0.8913 - recall: 0.8540 - val_loss: 0.6954 - val_accuracy: 0.7633 - val_precision: 0.7899 - val_recall: 0.7510
# Epoch 68/100
# 92/92 [==============================] - 59s 637ms/step - loss: 0.3006 - accuracy: 0.8830 - precision: 0.9024 - recall: 0.8687 - val_loss: 1.4991 - val_accuracy: 0.6607 - val_precision: 0.6695 - val_recall: 0.6512
# Epoch 69/100
# 92/92 [==============================] - 61s 661ms/step - loss: 0.2758 - accuracy: 0.8972 - precision: 0.9092 - recall: 0.8789 - val_loss: 0.9241 - val_accuracy: 0.7291 - val_precision: 0.7433 - val_recall: 0.7168
# Epoch 70/100
# 92/92 [==============================] - 59s 642ms/step - loss: 0.2910 - accuracy: 0.8945 - precision: 0.9089 - recall: 0.8792 - val_loss: 0.7801 - val_accuracy: 0.7538 - val_precision: 0.7744 - val_recall: 0.7278
# Epoch 71/100
# 92/92 [==============================] - 59s 646ms/step - loss: 0.2896 - accuracy: 0.8853 - precision: 0.9014 - recall: 0.8710 - val_loss: 0.9681 - val_accuracy: 0.7510 - val_precision: 0.7703 - val_recall: 0.7387
# Epoch 72/100
# 92/92 [==============================] - 59s 643ms/step - loss: 0.2590 - accuracy: 0.9017 - precision: 0.9145 - recall: 0.8884 - val_loss: 0.7772 - val_accuracy: 0.7948 - val_precision: 0.8031 - val_recall: 0.7811
# Epoch 73/100
# 92/92 [==============================] - 59s 637ms/step - loss: 0.3031 - accuracy: 0.8853 - precision: 0.9026 - recall: 0.8738 - val_loss: 0.7846 - val_accuracy: 0.7674 - val_precision: 0.7906 - val_recall: 0.7332
# Epoch 74/100
# 92/92 [==============================] - 59s 645ms/step - loss: 0.2702 - accuracy: 0.8942 - precision: 0.9078 - recall: 0.8813 - val_loss: 0.6932 - val_accuracy: 0.7893 - val_precision: 0.8026 - val_recall: 0.7729
# Epoch 75/100
# 92/92 [==============================] - 59s 642ms/step - loss: 0.2216 - accuracy: 0.9129 - precision: 0.9255 - recall: 0.9003 - val_loss: 0.7429 - val_accuracy: 0.7852 - val_precision: 0.8014 - val_recall: 0.7729
# Epoch 76/100
# 92/92 [==============================] - 58s 627ms/step - loss: 0.2918 - accuracy: 0.8918 - precision: 0.9070 - recall: 0.8826 - val_loss: 0.9328 - val_accuracy: 0.7497 - val_precision: 0.7712 - val_recall: 0.7332
# Epoch 77/100
# 92/92 [==============================] - 58s 633ms/step - loss: 0.2610 - accuracy: 0.8952 - precision: 0.9116 - recall: 0.8840 - val_loss: 0.7320 - val_accuracy: 0.7825 - val_precision: 0.7960 - val_recall: 0.7688
# Epoch 78/100
# 92/92 [==============================] - 58s 630ms/step - loss: 0.2685 - accuracy: 0.9027 - precision: 0.9162 - recall: 0.8857 - val_loss: 0.6358 - val_accuracy: 0.8194 - val_precision: 0.8345 - val_recall: 0.8071
# Epoch 79/100
# 92/92 [==============================] - 58s 631ms/step - loss: 0.2411 - accuracy: 0.9102 - precision: 0.9187 - recall: 0.9000 - val_loss: 0.8273 - val_accuracy: 0.7729 - val_precision: 0.7838 - val_recall: 0.7538
# Epoch 80/100
# 92/92 [==============================] - 58s 628ms/step - loss: 0.2699 - accuracy: 0.8945 - precision: 0.9065 - recall: 0.8840 - val_loss: 0.7558 - val_accuracy: 0.7770 - val_precision: 0.7915 - val_recall: 0.7633
# Epoch 81/100
# 92/92 [==============================] - 58s 634ms/step - loss: 0.2312 - accuracy: 0.9143 - precision: 0.9240 - recall: 0.9061 - val_loss: 0.6896 - val_accuracy: 0.7852 - val_precision: 0.8089 - val_recall: 0.7702
# Epoch 82/100
# 92/92 [==============================] - 58s 633ms/step - loss: 0.2505 - accuracy: 0.9023 - precision: 0.9143 - recall: 0.8932 - val_loss: 0.7688 - val_accuracy: 0.7880 - val_precision: 0.8051 - val_recall: 0.7743
# Epoch 83/100
# 92/92 [==============================] - 57s 624ms/step - loss: 0.2303 - accuracy: 0.9109 - precision: 0.9208 - recall: 0.9017 - val_loss: 0.8476 - val_accuracy: 0.7729 - val_precision: 0.7857 - val_recall: 0.7674
# Epoch 84/100
# 92/92 [==============================] - 57s 624ms/step - loss: 0.2536 - accuracy: 0.9037 - precision: 0.9163 - recall: 0.8938 - val_loss: 0.7083 - val_accuracy: 0.8003 - val_precision: 0.8150 - val_recall: 0.7893
# Epoch 85/100
# 92/92 [==============================] - 58s 626ms/step - loss: 0.2506 - accuracy: 0.9061 - precision: 0.9175 - recall: 0.8972 - val_loss: 0.8978 - val_accuracy: 0.7674 - val_precision: 0.7722 - val_recall: 0.7510
# Epoch 86/100
# 92/92 [==============================] - 58s 628ms/step - loss: 0.2423 - accuracy: 0.9068 - precision: 0.9158 - recall: 0.8989 - val_loss: 0.7034 - val_accuracy: 0.7770 - val_precision: 0.7937 - val_recall: 0.7579
# Epoch 87/100
# 92/92 [==============================] - 60s 653ms/step - loss: 0.2109 - accuracy: 0.9214 - precision: 0.9318 - recall: 0.9153 - val_loss: 0.7709 - val_accuracy: 0.7756 - val_precision: 0.8034 - val_recall: 0.7661
# Epoch 88/100
# 92/92 [==============================] - 60s 647ms/step - loss: 0.2367 - accuracy: 0.9109 - precision: 0.9185 - recall: 0.9013 - val_loss: 1.0358 - val_accuracy: 0.7715 - val_precision: 0.7799 - val_recall: 0.7661
# Epoch 89/100
# 92/92 [==============================] - 59s 643ms/step - loss: 0.2281 - accuracy: 0.9156 - precision: 0.9256 - recall: 0.9064 - val_loss: 0.8772 - val_accuracy: 0.7510 - val_precision: 0.7723 - val_recall: 0.7332
# Epoch 90/100
# 92/92 [==============================] - 59s 644ms/step - loss: 0.2357 - accuracy: 0.9143 - precision: 0.9240 - recall: 0.9058 - val_loss: 0.7774 - val_accuracy: 0.7674 - val_precision: 0.7934 - val_recall: 0.7565
# Epoch 91/100
# 92/92 [==============================] - 59s 644ms/step - loss: 0.2218 - accuracy: 0.9126 - precision: 0.9214 - recall: 0.9017 - val_loss: 0.7155 - val_accuracy: 0.7907 - val_precision: 0.8048 - val_recall: 0.7729
# Epoch 92/100
# 92/92 [==============================] - 60s 647ms/step - loss: 0.2145 - accuracy: 0.9183 - precision: 0.9289 - recall: 0.9119 - val_loss: 0.7080 - val_accuracy: 0.7866 - val_precision: 0.8008 - val_recall: 0.7756
# Epoch 93/100
# 92/92 [==============================] - 61s 663ms/step - loss: 0.2195 - accuracy: 0.9197 - precision: 0.9278 - recall: 0.9098 - val_loss: 1.0203 - val_accuracy: 0.7469 - val_precision: 0.7623 - val_recall: 0.7415
# Epoch 94/100
# 92/92 [==============================] - 61s 662ms/step - loss: 0.2149 - accuracy: 0.9163 - precision: 0.9261 - recall: 0.9081 - val_loss: 0.6618 - val_accuracy: 0.8085 - val_precision: 0.8132 - val_recall: 0.7921
# Epoch 95/100
# 92/92 [==============================] - 61s 664ms/step - loss: 0.1798 - accuracy: 0.9357 - precision: 0.9429 - recall: 0.9272 - val_loss: 0.7241 - val_accuracy: 0.8085 - val_precision: 0.8209 - val_recall: 0.7962
# Epoch 96/100
# 92/92 [==============================] - 61s 664ms/step - loss: 0.2052 - accuracy: 0.9251 - precision: 0.9315 - recall: 0.9200 - val_loss: 0.7694 - val_accuracy: 0.7934 - val_precision: 0.8102 - val_recall: 0.7825
# Epoch 97/100
# 92/92 [==============================] - 61s 658ms/step - loss: 0.2195 - accuracy: 0.9217 - precision: 0.9283 - recall: 0.9166 - val_loss: 0.8811 - val_accuracy: 0.7756 - val_precision: 0.7881 - val_recall: 0.7633
# Epoch 98/100
# 92/92 [==============================] - 61s 659ms/step - loss: 0.1903 - accuracy: 0.9299 - precision: 0.9352 - recall: 0.9234 - val_loss: 0.7491 - val_accuracy: 0.7729 - val_precision: 0.7859 - val_recall: 0.7633
# Epoch 99/100
# 92/92 [==============================] - 60s 656ms/step - loss: 0.1959 - accuracy: 0.9330 - precision: 0.9395 - recall: 0.9245 - val_loss: 0.6675 - val_accuracy: 0.7825 - val_precision: 0.8118 - val_recall: 0.7729
# Epoch 100/100
# 92/92 [==============================] - 60s 656ms/step - loss: 0.1986 - accuracy: 0.9255 - precision: 0.9322 - recall: 0.9170 - val_loss: 0.8429 - val_accuracy: 0.7811 - val_precision: 0.7901 - val_recall: 0.7674
# INFO:tensorflow:Assets written to: /tmp/tmphmqvoosu/model/data/model/assets

# %%
mpl.rcParams.update({'font.size': 10, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})

# %%
plt.figure(figsize=(20,5))
plt.plot(Result.history['accuracy'], label='accuracy')
plt.plot(Result.history['val_accuracy'], label='val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(list(range(1,100)))
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.figure(figsize=(20,5))
plt.plot(Result.history['loss'], label='train_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(list(range(1,100)))
plt.ylim([0, 2])
plt.legend(loc='lower right')

# %% [markdown]
# **Plot Evaluation**

# %%
model.save("07_model.h5")

# %%
def plot_example(X, y, y_pred=None):
# Create figure with 3 x 3 sub-plots.
  fig, axes = plt.subplots(3, 6)
  fig.set_size_inches(18,10)
  fig.subplots_adjust(hspace=0.3, wspace=0.3)
  X, y = X[:18, ..., 0], y[:18]
  for i, ax in enumerate(axes.flat):
    # Plot image.
    ax.imshow(X[i], alpha = 1)
    # Show true and predicted classes.
    if y_pred is None:
      xlabel = "True: {0}".format(y[i])
    else:
      xlabel = "True: {0}, Pred: {1}".format(y[i], y_pred[i])
    # Show the classes as the label on the x-axis.
    ax.set_xlabel(xlabel)
    # Remove ticks from the plot.
    ax.set_xticks([])
    ax.set_yticks([])
    # Ensure the plot is shown correctly with multiple plots in a single Notebook cell.
  plt.show()

# %%
model = tf.keras.models.load_model('07_model.h5')
#%matplotlib inline
# Make prediction
predictions = model.predict(x_test)
# retrieve prediction indices
pred_y = np.argmax(predictions, axis=1)
# Plot some examples with model predictions
plot_example(x_test, y_test, y_pred)
