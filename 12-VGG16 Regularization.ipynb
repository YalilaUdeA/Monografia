# %% [markdown]
# # Flower Classification
#
# **Exploracion de datos y Preprocesamiento**
#
# **Yalila Aljure Jimenez**
#
# email: yalila.aljure@udea.edu.co
#
# CC. 5288540

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.6.0'

# %%
import keras
keras.__version__
# Out:
# '2.6.0'

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import PIL
import pathlib
from mpl_toolkits.axes_grid1 import ImageGrid
from matplotlib import pyplot as plt
import random
import math 
from sklearn.metrics import roc_curve, auc, multilabel_confusion_matrix, plot_confusion_matrix, roc_auc_score
from keras.layers import Conv2D, Dropout, MaxPooling2D, BatchNormalization, Activation, Flatten, Dense, InputLayer, Input
from tensorflow.keras import regularizers, optimizers
from keras.models import Sequential, Model
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

# %% [markdown]
# **LOAD DATA**

# %%
# !wget https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# Out:
# --2021-10-23 02:02:04--  https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.159.128, 74.125.70.128, 74.125.202.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.159.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 228813984 (218M) [application/x-compressed-tar]
# Saving to: ‘flower_photos.tgz’
#
# flower_photos.tgz   100%[===================>] 218.21M   185MB/s    in 1.2s
#
# 2021-10-23 02:02:06 (185 MB/s) - ‘flower_photos.tgz’ saved [228813984/228813984]

# %%
# Unzipping Data
# !gunzip flower_photos.tgz
# Out:
# gzip: flower_photos.tar already exists; do you wish to overwrite (y or n)? y

# %%
# !tar -xvf flower_photos.tar

# %% [markdown]
# **Plotting Images**

# %%
data_dir = pathlib.Path('flower_photos')
folder = list(data_dir.glob('*'))
images = list(data_dir.glob('*/*.jpg')) #list of all images (full path)

# %%
len(images) # Number of images
# Out:
# 3670

# %%
fig = plt.figure(figsize=(20, 20))
iterable = np.array(random.sample(range(1, 3670), 54)) # Choosing 54 random images
for i in range(54):
    plt.subplot(9, 6, i+1)
    j = iterable[i]
    plt.title(str(images[j]).split('/')[-1], fontsize=10) # file name and disply as title
    plt.imshow(PIL.Image.open(images[j])) # Displaying Image
    ax = plt.axis("off")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Parameters**

# %%
image_size = 224 # Setting the size of the images
b_size = 32

# %% [markdown]
# **Imagen Preprocessing**
#
# Data Augmantation

# %% [markdown]
# Original source is not partitioned. The test set will be fixed at 20% of the entire dataset. The rest of the dataset will be used for training (0.8) and validation (0.2).

# %%
idg_flip = tf.keras.preprocessing.image.ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest',
    validation_split = 0.2
)

# %%
flower_gen_train = idg_flip.flow_from_directory(data_dir,
                                    target_size=(image_size, image_size),
                                    batch_size=b_size,
                                    subset='training',
                                    class_mode='categorical',
                                    shuffle=True,
                                    seed=123
                                    )
# Out:
# Found 2939 images belonging to 5 classes.

# %%
flower_gen_test = idg_flip.flow_from_directory(data_dir,
                                    target_size=(image_size, image_size),
                                    batch_size=b_size,
                                    subset='validation',
                                    class_mode='categorical',
                                    shuffle=True,
                                    seed=123
                                    )
# Out:
# Found 731 images belonging to 5 classes.

# %% [markdown]
# **VGGNet**

# %%
# Instanciate and empty model
model = Sequential()
# First Convolutional Layer
model.add(Conv2D(64, kernel_size=(3,3), activation='PReLU',padding='same',input_shape=(image_size,image_size,3))) # 2D Convolution layer, filters = 64
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(64, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 64
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(BatchNormalization()) 
# Second Convolutional Layer
model.add(Conv2D(128, kernel_size=(3,3), activation='PReLU', padding='same')) # 2D Convolution layer, filters = 128
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(128, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 128
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(BatchNormalization()) 
# Third Convolutional Layer
model.add(Conv2D(256, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 256
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(256, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 256
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(256, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 256
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(BatchNormalization()) 
# Fourth Convolutional Layer
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(BatchNormalization()) 
# Fith convolutional layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(BatchNormalization()) 
# 1st dense layer
model.add(Flatten()) 
model.add(Dense(4096,kernel_regularizer=regularizers.l2(l2=0.05)))
# Dropout
model.add(Dropout(0.5)) 
model.add(Activation('PReLU'))
# 2nd Dense Layer
model.add(Dense(4096,kernel_regularizer=regularizers.l2(l2=0.05)))
# Dropout
model.add(Dropout(0.5))
# Normalization
model.add(BatchNormalization()) 
model.add(Activation('PReLU'))
# Output softmax layer
model.add(Dense(5))
model.add(Activation('softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy','Precision','Recall'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      3213056
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      839744
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 56, 56, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 128)       475264
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 128)       247936
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 256)       345344
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 256)         602624
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 256)         592384
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1, 1, 256)         1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 1, 512)         1180672
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1, 1, 512)         2048
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1, 1, 512)         2048
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# activation (Activation)      (None, 4096)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4096)              16384
# _________________________________________________________________
# activation_1 (Activation)    (None, 4096)              4096
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 20485
# _________________________________________________________________
# activation_2 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 38,232,133
# Trainable params: 38,220,997
# Non-trainable params: 11,136
# _________________________________________________________________

# %%
Result = model.fit(flower_gen_train, validation_data=flower_gen_test
                   , epochs=100, verbose=1, shuffle=True)
# Out:
# Epoch 1/100
# 92/92 [==============================] - 73s 727ms/step - loss: 41.7891 - accuracy: 0.2480 - precision: 0.2889 - recall: 0.0745 - val_loss: 6.0007 - val_accuracy: 0.2462 - val_precision: 0.2720 - val_recall: 0.0889
# Epoch 2/100
# 92/92 [==============================] - 64s 698ms/step - loss: 5.7545 - accuracy: 0.2879 - precision: 0.3808 - recall: 0.0810 - val_loss: 10.8187 - val_accuracy: 0.2408 - val_precision: 0.2440 - val_recall: 0.2353
# Epoch 3/100
# 92/92 [==============================] - 64s 696ms/step - loss: 5.6500 - accuracy: 0.3692 - precision: 0.4531 - recall: 0.1776 - val_loss: 5.5631 - val_accuracy: 0.3051 - val_precision: 0.4400 - val_recall: 0.0150
# Epoch 4/100
# 92/92 [==============================] - 64s 697ms/step - loss: 5.8286 - accuracy: 0.3569 - precision: 0.4370 - recall: 0.1630 - val_loss: 5.6306 - val_accuracy: 0.2777 - val_precision: 0.5000 - val_recall: 0.0178
# Epoch 5/100
# 92/92 [==============================] - 64s 697ms/step - loss: 6.0248 - accuracy: 0.3641 - precision: 0.4199 - recall: 0.1562 - val_loss: 5.7340 - val_accuracy: 0.2476 - val_precision: 0.0661 - val_recall: 0.0109
# Epoch 6/100
# 92/92 [==============================] - 64s 697ms/step - loss: 5.8398 - accuracy: 0.3770 - precision: 0.4272 - recall: 0.1786 - val_loss: 6.2827 - val_accuracy: 0.3092 - val_precision: 0.3061 - val_recall: 0.0410
# Epoch 7/100
# 92/92 [==============================] - 64s 699ms/step - loss: 5.8121 - accuracy: 0.3358 - precision: 0.4000 - recall: 0.1313 - val_loss: 5.7135 - val_accuracy: 0.3010 - val_precision: 0.4944 - val_recall: 0.0602
# Epoch 8/100
# 92/92 [==============================] - 64s 697ms/step - loss: 5.0648 - accuracy: 0.3471 - precision: 0.4519 - recall: 0.1310 - val_loss: 9.6154 - val_accuracy: 0.2531 - val_precision: 0.4126 - val_recall: 0.1614
# Epoch 9/100
# 92/92 [==============================] - 64s 696ms/step - loss: 5.3099 - accuracy: 0.3675 - precision: 0.4459 - recall: 0.1375 - val_loss: 5.5720 - val_accuracy: 0.3105 - val_precision: 0.5522 - val_recall: 0.0506
# Epoch 10/100
# 92/92 [==============================] - 64s 693ms/step - loss: 4.9380 - accuracy: 0.3852 - precision: 0.4962 - recall: 0.1780 - val_loss: 5.4942 - val_accuracy: 0.4309 - val_precision: 0.4335 - val_recall: 0.1026
# Epoch 11/100
# 92/92 [==============================] - 64s 693ms/step - loss: 5.3261 - accuracy: 0.4042 - precision: 0.4902 - recall: 0.1793 - val_loss: 5.1502 - val_accuracy: 0.3228 - val_precision: 0.2653 - val_recall: 0.0534
# Epoch 12/100
# 92/92 [==============================] - 64s 692ms/step - loss: 5.5299 - accuracy: 0.4274 - precision: 0.4799 - recall: 0.2310 - val_loss: 5.7699 - val_accuracy: 0.3037 - val_precision: 0.4429 - val_recall: 0.0424
# Epoch 13/100
# 92/92 [==============================] - 64s 698ms/step - loss: 5.3075 - accuracy: 0.4280 - precision: 0.4943 - recall: 0.2218 - val_loss: 5.6623 - val_accuracy: 0.4008 - val_precision: 0.5333 - val_recall: 0.0876
# Epoch 14/100
# 92/92 [==============================] - 64s 695ms/step - loss: 4.8114 - accuracy: 0.4311 - precision: 0.5091 - recall: 0.2385 - val_loss: 5.8179 - val_accuracy: 0.4118 - val_precision: 0.4468 - val_recall: 0.0862
# Epoch 15/100
# 92/92 [==============================] - 64s 695ms/step - loss: 4.5625 - accuracy: 0.4502 - precision: 0.5284 - recall: 0.2528 - val_loss: 5.0178 - val_accuracy: 0.3201 - val_precision: 0.5431 - val_recall: 0.0862
# Epoch 16/100
# 92/92 [==============================] - 64s 694ms/step - loss: 4.4828 - accuracy: 0.4702 - precision: 0.5606 - recall: 0.2957 - val_loss: 4.5162 - val_accuracy: 0.3611 - val_precision: 0.6188 - val_recall: 0.1710
# Epoch 17/100
# 92/92 [==============================] - 64s 692ms/step - loss: 4.3156 - accuracy: 0.4815 - precision: 0.5658 - recall: 0.3072 - val_loss: 4.3711 - val_accuracy: 0.3899 - val_precision: 0.3585 - val_recall: 0.0260
# Epoch 18/100
# 92/92 [==============================] - 64s 697ms/step - loss: 4.0792 - accuracy: 0.4954 - precision: 0.5656 - recall: 0.3460 - val_loss: 5.0337 - val_accuracy: 0.4870 - val_precision: 0.6520 - val_recall: 0.1819
# Epoch 19/100
# 92/92 [==============================] - 64s 695ms/step - loss: 3.8848 - accuracy: 0.5291 - precision: 0.6259 - recall: 0.3746 - val_loss: 3.9841 - val_accuracy: 0.4049 - val_precision: 0.5882 - val_recall: 0.1778
# Epoch 20/100
# 92/92 [==============================] - 64s 694ms/step - loss: 3.6812 - accuracy: 0.5567 - precision: 0.6481 - recall: 0.4243 - val_loss: 4.2373 - val_accuracy: 0.5157 - val_precision: 0.6685 - val_recall: 0.1655
# Epoch 21/100
# 92/92 [==============================] - 64s 695ms/step - loss: 3.6871 - accuracy: 0.5454 - precision: 0.6209 - recall: 0.3940 - val_loss: 3.8282 - val_accuracy: 0.3146 - val_precision: 0.6579 - val_recall: 0.2052
# Epoch 22/100
# 92/92 [==============================] - 64s 692ms/step - loss: 3.4416 - accuracy: 0.5512 - precision: 0.6403 - recall: 0.4178 - val_loss: 3.5091 - val_accuracy: 0.4569 - val_precision: 0.6270 - val_recall: 0.1081
# Epoch 23/100
# 92/92 [==============================] - 64s 695ms/step - loss: 3.4371 - accuracy: 0.5601 - precision: 0.6474 - recall: 0.4423 - val_loss: 4.2161 - val_accuracy: 0.5376 - val_precision: 0.6720 - val_recall: 0.1149
# Epoch 24/100
# 92/92 [==============================] - 64s 695ms/step - loss: 3.2009 - accuracy: 0.5713 - precision: 0.6630 - recall: 0.4304 - val_loss: 3.2942 - val_accuracy: 0.4925 - val_precision: 0.7814 - val_recall: 0.2982
# Epoch 25/100
# 92/92 [==============================] - 64s 690ms/step - loss: 3.0773 - accuracy: 0.5791 - precision: 0.6735 - recall: 0.4471 - val_loss: 3.2654 - val_accuracy: 0.3776 - val_precision: 0.5123 - val_recall: 0.2572
# Epoch 26/100
# 92/92 [==============================] - 64s 691ms/step - loss: 2.9038 - accuracy: 0.5900 - precision: 0.6826 - recall: 0.4675 - val_loss: 3.2621 - val_accuracy: 0.4747 - val_precision: 0.7971 - val_recall: 0.0752
# Epoch 27/100
# 92/92 [==============================] - 63s 686ms/step - loss: 3.0053 - accuracy: 0.5927 - precision: 0.6689 - recall: 0.4729 - val_loss: 3.0902 - val_accuracy: 0.4049 - val_precision: 0.6376 - val_recall: 0.1300
# Epoch 28/100
# 92/92 [==============================] - 64s 691ms/step - loss: 2.7864 - accuracy: 0.5961 - precision: 0.7071 - recall: 0.4665 - val_loss: 4.0749 - val_accuracy: 0.5404 - val_precision: 0.6590 - val_recall: 0.1560
# Epoch 29/100
# 92/92 [==============================] - 64s 699ms/step - loss: 2.9884 - accuracy: 0.6039 - precision: 0.6955 - recall: 0.4685 - val_loss: 3.2560 - val_accuracy: 0.4966 - val_precision: 0.8125 - val_recall: 0.1067
# Epoch 30/100
# 92/92 [==============================] - 64s 695ms/step - loss: 2.9422 - accuracy: 0.5910 - precision: 0.6894 - recall: 0.4682 - val_loss: 3.0271 - val_accuracy: 0.5321 - val_precision: 0.6383 - val_recall: 0.0410
# Epoch 31/100
# 92/92 [==============================] - 64s 694ms/step - loss: 2.6978 - accuracy: 0.6142 - precision: 0.7117 - recall: 0.4855 - val_loss: 3.3056 - val_accuracy: 0.4555 - val_precision: 0.7333 - val_recall: 0.1655
# Epoch 32/100
# 92/92 [==============================] - 64s 695ms/step - loss: 2.9918 - accuracy: 0.5886 - precision: 0.6952 - recall: 0.4787 - val_loss: 3.2119 - val_accuracy: 0.4241 - val_precision: 0.7143 - val_recall: 0.0274
# Epoch 33/100
# 92/92 [==============================] - 64s 693ms/step - loss: 2.8601 - accuracy: 0.6050 - precision: 0.7045 - recall: 0.4777 - val_loss: 3.2305 - val_accuracy: 0.4911 - val_precision: 0.6429 - val_recall: 0.1970
# Epoch 34/100
# 92/92 [==============================] - 64s 696ms/step - loss: 2.7315 - accuracy: 0.6125 - precision: 0.7141 - recall: 0.5015 - val_loss: 3.0957 - val_accuracy: 0.4679 - val_precision: 0.7985 - val_recall: 0.1464
# Epoch 35/100
# 92/92 [==============================] - 64s 695ms/step - loss: 2.8096 - accuracy: 0.6026 - precision: 0.7151 - recall: 0.4886 - val_loss: 5.3833 - val_accuracy: 0.6224 - val_precision: 0.7509 - val_recall: 0.2763
# Epoch 36/100
# 92/92 [==============================] - 64s 698ms/step - loss: 2.7408 - accuracy: 0.6039 - precision: 0.7051 - recall: 0.4801 - val_loss: 3.1175 - val_accuracy: 0.4870 - val_precision: 0.7354 - val_recall: 0.2585
# Epoch 37/100
# 92/92 [==============================] - 64s 694ms/step - loss: 2.7275 - accuracy: 0.6148 - precision: 0.7120 - recall: 0.5114 - val_loss: 2.9405 - val_accuracy: 0.6320 - val_precision: 0.9552 - val_recall: 0.0876
# Epoch 38/100
# 92/92 [==============================] - 64s 697ms/step - loss: 2.8847 - accuracy: 0.5832 - precision: 0.6927 - recall: 0.4709 - val_loss: 2.8037 - val_accuracy: 0.4993 - val_precision: 0.8431 - val_recall: 0.1176
# Epoch 39/100
# 92/92 [==============================] - 64s 696ms/step - loss: 2.4436 - accuracy: 0.6060 - precision: 0.7044 - recall: 0.4719 - val_loss: 2.9954 - val_accuracy: 0.5978 - val_precision: 0.7251 - val_recall: 0.2490
# Epoch 40/100
# 92/92 [==============================] - 64s 697ms/step - loss: 2.2449 - accuracy: 0.6097 - precision: 0.7200 - recall: 0.4934 - val_loss: 2.6130 - val_accuracy: 0.4391 - val_precision: 0.9167 - val_recall: 0.0301
# Epoch 41/100
# 92/92 [==============================] - 64s 696ms/step - loss: 2.1496 - accuracy: 0.5907 - precision: 0.7166 - recall: 0.4570 - val_loss: 2.2764 - val_accuracy: 0.4938 - val_precision: 0.9103 - val_recall: 0.0971
# Epoch 42/100
# 92/92 [==============================] - 64s 696ms/step - loss: 2.1889 - accuracy: 0.5832 - precision: 0.7004 - recall: 0.4573 - val_loss: 2.3002 - val_accuracy: 0.4829 - val_precision: 0.7087 - val_recall: 0.2230
# Epoch 43/100
# 92/92 [==============================] - 64s 695ms/step - loss: 1.8770 - accuracy: 0.6233 - precision: 0.7259 - recall: 0.5002 - val_loss: 2.2156 - val_accuracy: 0.6019 - val_precision: 0.9810 - val_recall: 0.1409
# Epoch 44/100
# 92/92 [==============================] - 64s 690ms/step - loss: 1.8994 - accuracy: 0.6271 - precision: 0.7341 - recall: 0.4988 - val_loss: 1.9493 - val_accuracy: 0.6566 - val_precision: 0.9116 - val_recall: 0.2257
# Epoch 45/100
# 92/92 [==============================] - 64s 695ms/step - loss: 1.7697 - accuracy: 0.6407 - precision: 0.7440 - recall: 0.5162 - val_loss: 2.0429 - val_accuracy: 0.5144 - val_precision: 0.7798 - val_recall: 0.1792
# Epoch 46/100
# 92/92 [==============================] - 64s 697ms/step - loss: 1.9747 - accuracy: 0.6227 - precision: 0.7259 - recall: 0.4974 - val_loss: 2.0638 - val_accuracy: 0.6347 - val_precision: 0.8873 - val_recall: 0.2476
# Epoch 47/100
# 92/92 [==============================] - 64s 693ms/step - loss: 1.7863 - accuracy: 0.6431 - precision: 0.7418 - recall: 0.5250 - val_loss: 2.1212 - val_accuracy: 0.5445 - val_precision: 0.8829 - val_recall: 0.2476
# Epoch 48/100
# 92/92 [==============================] - 64s 690ms/step - loss: 1.6918 - accuracy: 0.6536 - precision: 0.7603 - recall: 0.5515 - val_loss: 1.8572 - val_accuracy: 0.6252 - val_precision: 0.9022 - val_recall: 0.2271
# Epoch 49/100
# 92/92 [==============================] - 64s 693ms/step - loss: 1.6274 - accuracy: 0.6601 - precision: 0.7701 - recall: 0.5515 - val_loss: 2.0584 - val_accuracy: 0.5390 - val_precision: 0.9067 - val_recall: 0.0930
# Epoch 50/100
# 92/92 [==============================] - 64s 692ms/step - loss: 1.7088 - accuracy: 0.6632 - precision: 0.7624 - recall: 0.5383 - val_loss: 1.9152 - val_accuracy: 0.6375 - val_precision: 0.9528 - val_recall: 0.2763
# Epoch 51/100
# 92/92 [==============================] - 64s 695ms/step - loss: 1.7810 - accuracy: 0.6672 - precision: 0.7520 - recall: 0.5655 - val_loss: 2.1051 - val_accuracy: 0.6347 - val_precision: 0.8826 - val_recall: 0.2777
# Epoch 52/100
# 92/92 [==============================] - 64s 693ms/step - loss: 1.8512 - accuracy: 0.6404 - precision: 0.7505 - recall: 0.5260 - val_loss: 1.8919 - val_accuracy: 0.6115 - val_precision: 0.8308 - val_recall: 0.3694
# Epoch 53/100
# 92/92 [==============================] - 64s 694ms/step - loss: 1.7197 - accuracy: 0.6666 - precision: 0.7524 - recall: 0.5543 - val_loss: 2.0780 - val_accuracy: 0.5882 - val_precision: 0.8327 - val_recall: 0.2859
# Epoch 54/100
# 92/92 [==============================] - 64s 694ms/step - loss: 2.0108 - accuracy: 0.6686 - precision: 0.7662 - recall: 0.5553 - val_loss: 2.0512 - val_accuracy: 0.6457 - val_precision: 0.7890 - val_recall: 0.3529
# Epoch 55/100
# 92/92 [==============================] - 64s 693ms/step - loss: 1.8249 - accuracy: 0.6693 - precision: 0.7763 - recall: 0.5740 - val_loss: 1.9679 - val_accuracy: 0.6197 - val_precision: 0.9316 - val_recall: 0.2421
# Epoch 56/100
# 92/92 [==============================] - 64s 698ms/step - loss: 1.7488 - accuracy: 0.6829 - precision: 0.7748 - recall: 0.5771 - val_loss: 2.0805 - val_accuracy: 0.6361 - val_precision: 0.9215 - val_recall: 0.2408
# Epoch 57/100
# 92/92 [==============================] - 64s 693ms/step - loss: 1.6264 - accuracy: 0.6941 - precision: 0.7670 - recall: 0.6050 - val_loss: 2.0663 - val_accuracy: 0.6443 - val_precision: 0.9174 - val_recall: 0.2886
# Epoch 58/100
# 92/92 [==============================] - 64s 693ms/step - loss: 1.8702 - accuracy: 0.6866 - precision: 0.7691 - recall: 0.5893 - val_loss: 2.6746 - val_accuracy: 0.5609 - val_precision: 0.7178 - val_recall: 0.2367
# Epoch 59/100
# 92/92 [==============================] - 64s 690ms/step - loss: 1.9403 - accuracy: 0.6992 - precision: 0.7765 - recall: 0.6005 - val_loss: 2.1654 - val_accuracy: 0.6129 - val_precision: 0.8844 - val_recall: 0.2408
# Epoch 60/100
# 92/92 [==============================] - 64s 694ms/step - loss: 1.9907 - accuracy: 0.6945 - precision: 0.7771 - recall: 0.6050 - val_loss: 2.8161 - val_accuracy: 0.5554 - val_precision: 0.7163 - val_recall: 0.2038
# Epoch 61/100
# 92/92 [==============================] - 64s 699ms/step - loss: 2.1954 - accuracy: 0.6982 - precision: 0.7756 - recall: 0.6033 - val_loss: 2.3263 - val_accuracy: 0.6457 - val_precision: 1.0000 - val_recall: 0.1546
# Epoch 62/100
# 92/92 [==============================] - 64s 699ms/step - loss: 1.9583 - accuracy: 0.7006 - precision: 0.7782 - recall: 0.6053 - val_loss: 2.2901 - val_accuracy: 0.6539 - val_precision: 0.9569 - val_recall: 0.3338
# Epoch 63/100
# 92/92 [==============================] - 64s 696ms/step - loss: 1.9868 - accuracy: 0.6955 - precision: 0.7822 - recall: 0.6073 - val_loss: 2.2084 - val_accuracy: 0.6471 - val_precision: 0.9424 - val_recall: 0.3133
# Epoch 64/100
# 92/92 [==============================] - 64s 693ms/step - loss: 1.8962 - accuracy: 0.7091 - precision: 0.7906 - recall: 0.6308 - val_loss: 2.5550 - val_accuracy: 0.6854 - val_precision: 1.0000 - val_recall: 0.0807
# Epoch 65/100
# 92/92 [==============================] - 64s 694ms/step - loss: 2.1898 - accuracy: 0.7176 - precision: 0.7857 - recall: 0.6363 - val_loss: 2.8566 - val_accuracy: 0.6306 - val_precision: 0.9517 - val_recall: 0.1888
# Epoch 66/100
# 92/92 [==============================] - 64s 697ms/step - loss: 2.1616 - accuracy: 0.7254 - precision: 0.8071 - recall: 0.6465 - val_loss: 2.8682 - val_accuracy: 0.6211 - val_precision: 1.0000 - val_recall: 0.0766
# Epoch 67/100
# 92/92 [==============================] - 64s 698ms/step - loss: 2.3433 - accuracy: 0.7050 - precision: 0.7848 - recall: 0.6094 - val_loss: 2.5378 - val_accuracy: 0.6594 - val_precision: 0.9810 - val_recall: 0.2120
# Epoch 68/100
# 92/92 [==============================] - 64s 693ms/step - loss: 1.9047 - accuracy: 0.7336 - precision: 0.7973 - recall: 0.6625 - val_loss: 2.7009 - val_accuracy: 0.5691 - val_precision: 0.7622 - val_recall: 0.1929
# Epoch 69/100
# 92/92 [==============================] - 64s 698ms/step - loss: 1.9429 - accuracy: 0.7462 - precision: 0.8123 - recall: 0.6730 - val_loss: 2.3766 - val_accuracy: 0.7141 - val_precision: 0.9718 - val_recall: 0.1888
# Epoch 70/100
# 92/92 [==============================] - 64s 695ms/step - loss: 1.9763 - accuracy: 0.7397 - precision: 0.8044 - recall: 0.6689 - val_loss: 2.4413 - val_accuracy: 0.6005 - val_precision: 0.6822 - val_recall: 0.0999
# Epoch 71/100
# 92/92 [==============================] - 64s 695ms/step - loss: 2.1143 - accuracy: 0.7482 - precision: 0.8078 - recall: 0.6720 - val_loss: 2.7825 - val_accuracy: 0.6430 - val_precision: 0.7670 - val_recall: 0.2161
# Epoch 72/100
# 92/92 [==============================] - 64s 697ms/step - loss: 2.4236 - accuracy: 0.7383 - precision: 0.7994 - recall: 0.6591 - val_loss: 2.4577 - val_accuracy: 0.6908 - val_precision: 0.9823 - val_recall: 0.1518
# Epoch 73/100
# 92/92 [==============================] - 64s 695ms/step - loss: 2.0176 - accuracy: 0.7486 - precision: 0.8115 - recall: 0.6839 - val_loss: 3.0514 - val_accuracy: 0.5157 - val_precision: 0.9512 - val_recall: 0.1067
# Epoch 74/100
# 92/92 [==============================] - 64s 693ms/step - loss: 2.2318 - accuracy: 0.7332 - precision: 0.8068 - recall: 0.6679 - val_loss: 2.9695 - val_accuracy: 0.6580 - val_precision: 0.9477 - val_recall: 0.1984
# Epoch 75/100
# 92/92 [==============================] - 64s 696ms/step - loss: 2.0319 - accuracy: 0.7349 - precision: 0.7991 - recall: 0.6700 - val_loss: 2.5443 - val_accuracy: 0.5951 - val_precision: 0.9796 - val_recall: 0.1313
# Epoch 76/100
# 92/92 [==============================] - 64s 695ms/step - loss: 2.1088 - accuracy: 0.7448 - precision: 0.8097 - recall: 0.6849 - val_loss: 3.0404 - val_accuracy: 0.6170 - val_precision: 1.0000 - val_recall: 0.0985
# Epoch 77/100
# 92/92 [==============================] - 64s 698ms/step - loss: 2.3275 - accuracy: 0.7339 - precision: 0.8123 - recall: 0.6580 - val_loss: 2.6299 - val_accuracy: 0.6375 - val_precision: 0.9550 - val_recall: 0.2613
# Epoch 78/100
# 92/92 [==============================] - 64s 691ms/step - loss: 2.2520 - accuracy: 0.7523 - precision: 0.8188 - recall: 0.6917 - val_loss: 2.8391 - val_accuracy: 0.6895 - val_precision: 0.9706 - val_recall: 0.0903
# Epoch 79/100
# 92/92 [==============================] - 64s 697ms/step - loss: 2.3771 - accuracy: 0.7710 - precision: 0.8276 - recall: 0.7091 - val_loss: 3.0919 - val_accuracy: 0.6826 - val_precision: 1.0000 - val_recall: 0.0930
# Epoch 80/100
# 92/92 [==============================] - 64s 698ms/step - loss: 2.2893 - accuracy: 0.7560 - precision: 0.8199 - recall: 0.7033 - val_loss: 3.8808 - val_accuracy: 0.3570 - val_precision: 0.6500 - val_recall: 0.0356
# Epoch 81/100
# 92/92 [==============================] - 64s 696ms/step - loss: 3.4779 - accuracy: 0.7196 - precision: 0.7974 - recall: 0.6335 - val_loss: 3.1392 - val_accuracy: 0.5609 - val_precision: 0.9672 - val_recall: 0.0807
# Epoch 82/100
# 92/92 [==============================] - 64s 697ms/step - loss: 2.5387 - accuracy: 0.7475 - precision: 0.8142 - recall: 0.6771 - val_loss: 3.4098 - val_accuracy: 0.5609 - val_precision: 0.9556 - val_recall: 0.1176
# Epoch 83/100
# 92/92 [==============================] - 64s 694ms/step - loss: 2.4970 - accuracy: 0.7727 - precision: 0.8346 - recall: 0.7210 - val_loss: 3.0389 - val_accuracy: 0.5499 - val_precision: 0.9706 - val_recall: 0.0903
# Epoch 84/100
# 92/92 [==============================] - 64s 693ms/step - loss: 2.3432 - accuracy: 0.7720 - precision: 0.8284 - recall: 0.7111 - val_loss: 3.1122 - val_accuracy: 0.5540 - val_precision: 0.9778 - val_recall: 0.1204
# Epoch 85/100
# 92/92 [==============================] - 64s 692ms/step - loss: 3.3527 - accuracy: 0.7482 - precision: 0.8149 - recall: 0.6829 - val_loss: 3.2203 - val_accuracy: 0.6033 - val_precision: 1.0000 - val_recall: 0.0643
# Epoch 86/100
# 92/92 [==============================] - 64s 695ms/step - loss: 2.6858 - accuracy: 0.7503 - precision: 0.8067 - recall: 0.6887 - val_loss: 2.9788 - val_accuracy: 0.5923 - val_precision: 0.9651 - val_recall: 0.1135
# Epoch 87/100
# 92/92 [==============================] - 64s 695ms/step - loss: 3.0313 - accuracy: 0.7591 - precision: 0.8178 - recall: 0.6904 - val_loss: 3.4874 - val_accuracy: 0.5554 - val_precision: 0.9836 - val_recall: 0.0821
# Epoch 88/100
# 92/92 [==============================] - 64s 696ms/step - loss: 2.3598 - accuracy: 0.7632 - precision: 0.8248 - recall: 0.7047 - val_loss: 2.8203 - val_accuracy: 0.6963 - val_precision: 1.0000 - val_recall: 0.0862
# Epoch 89/100
# 92/92 [==============================] - 64s 697ms/step - loss: 2.3348 - accuracy: 0.7703 - precision: 0.8290 - recall: 0.7094 - val_loss: 2.9689 - val_accuracy: 0.6443 - val_precision: 0.9000 - val_recall: 0.0616
# Epoch 90/100
# 92/92 [==============================] - 64s 694ms/step - loss: 2.4879 - accuracy: 0.7758 - precision: 0.8225 - recall: 0.7237 - val_loss: 3.3156 - val_accuracy: 0.6224 - val_precision: 0.9796 - val_recall: 0.0657
# Epoch 91/100
# 92/92 [==============================] - 64s 693ms/step - loss: 2.3978 - accuracy: 0.7938 - precision: 0.8446 - recall: 0.7435 - val_loss: 3.7570 - val_accuracy: 0.5978 - val_precision: 1.0000 - val_recall: 0.1313
# Epoch 92/100
# 92/92 [==============================] - 64s 697ms/step - loss: 2.5125 - accuracy: 0.8200 - precision: 0.8608 - recall: 0.7683 - val_loss: 2.9069 - val_accuracy: 0.6142 - val_precision: 0.9767 - val_recall: 0.0575
# Epoch 93/100
# 92/92 [==============================] - 65s 701ms/step - loss: 2.1326 - accuracy: 0.7986 - precision: 0.8327 - recall: 0.7537 - val_loss: 3.2242 - val_accuracy: 0.5718 - val_precision: 1.0000 - val_recall: 0.1382
# Epoch 94/100
# 92/92 [==============================] - 64s 695ms/step - loss: 2.5775 - accuracy: 0.7938 - precision: 0.8488 - recall: 0.7431 - val_loss: 3.4517 - val_accuracy: 0.5568 - val_precision: 0.7209 - val_recall: 0.0848
# Epoch 95/100
# 92/92 [==============================] - 64s 697ms/step - loss: 2.2978 - accuracy: 0.7941 - precision: 0.8421 - recall: 0.7458 - val_loss: 2.8604 - val_accuracy: 0.5937 - val_precision: 1.0000 - val_recall: 0.0328
# Epoch 96/100
# 92/92 [==============================] - 64s 697ms/step - loss: 2.0138 - accuracy: 0.8095 - precision: 0.8512 - recall: 0.7669 - val_loss: 2.6580 - val_accuracy: 0.6977 - val_precision: 0.9826 - val_recall: 0.1546
# Epoch 97/100
# 92/92 [==============================] - 64s 695ms/step - loss: 1.9949 - accuracy: 0.8088 - precision: 0.8555 - recall: 0.7557 - val_loss: 2.8757 - val_accuracy: 0.7086 - val_precision: 0.9913 - val_recall: 0.1560
# Epoch 98/100
# 92/92 [==============================] - 64s 700ms/step - loss: 2.0401 - accuracy: 0.8163 - precision: 0.8609 - recall: 0.7751 - val_loss: 2.9479 - val_accuracy: 0.7278 - val_precision: 0.9647 - val_recall: 0.2244
# Epoch 99/100
# 92/92 [==============================] - 64s 698ms/step - loss: 2.1316 - accuracy: 0.8261 - precision: 0.8598 - recall: 0.7822 - val_loss: 2.8570 - val_accuracy: 0.6621 - val_precision: 0.9495 - val_recall: 0.2572
# Epoch 100/100
# 92/92 [==============================] - 64s 697ms/step - loss: 2.1177 - accuracy: 0.8132 - precision: 0.8579 - recall: 0.7744 - val_loss: 2.8504 - val_accuracy: 0.7018 - val_precision: 0.9583 - val_recall: 0.1888

# %%
mpl.rcParams.update({'font.size': 10, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})

# %%
plt.figure(figsize=(20,5))
plt.plot(Result.history['accuracy'], label='accuracy')
plt.plot(Result.history['val_accuracy'], label='val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(list(range(1,100)))
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.figure(figsize=(20,5))
plt.plot(Result.history['loss'], label='train_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(list(range(1,100)))
plt.ylim([0, 50])
plt.legend(loc='lower right')

# %%
flower_gen_test.reset()
x_test, y_test = next(flower_gen_test)
for i in tqdm(range(int(len(flower_gen_test.labels)/b_size))):
  img, label = next(flower_gen_test)
  x_test = np.append(x_test, img, axis = 0)
  y_test = np.append(y_test, label, axis = 0)

print(x_test.shape,y_test.shape)
# Out:
# 100%|██████████| 22/22 [00:10<00:00,  2.08it/s]
# (731, 224, 224, 3) (731, 5)

# %%
#plt.figure(figsize=(10,5))
y_pred = model.predict(x_test)
#y_pred = model.predict(x_test).ravel()
#fpr, tpr, thresholds = roc_curve(y_test.ravel(), y_pred)
auc_keras = roc_auc_score(y_test,y_pred,multi_class='ovr')
print("ROC AUC score OVR:" + str(auc_keras))
#plt.title("ROC AUC score:" + str(auc_keras))
#plt.plot(y_test,y_pred, marker = ".")
auc_keras = roc_auc_score(y_test,y_pred,multi_class='ovo')
print("ROC AUC score OVO:" + str(auc_keras))
# Out:
# ROC AUC score OVR:0.9227227425281586
# ROC AUC score OVO:0.9227227425281586

# %% [markdown]
# The higher the AUC, the better performance of the model at distinguishing between the positives and negatives classes

# %% [markdown]
# **Final Scores**

# %% [markdown]
# Accuracy = $\frac{(TP+TN)}{(TP+FP+TN+FN)}$
#
# Precision = $\frac{TP}{(TP+FP)}$
#
# Recall =$\frac{TP}{(TP+FN)}$

# %%
y_pred = model.predict(x_test)
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_test, axis=1)

# %%
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
flower_labels = flower_gen_train.class_indices.keys()
print(flower_labels)
# Out:
# dict_keys(['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips'])

# %%
plot_confusion_matrix(y_test, y_pred, classes=np.r_[0,1,2,3,4], normalize=True, cmap=plt.cm.PuBu)
# Out:
# Normalized confusion matrix
# [[0.83333333 0.05555556 0.03174603 0.         0.07936508]
#  [0.08379888 0.8603352  0.01117318 0.01117318 0.03351955]
#  [0.0390625  0.0859375  0.5078125  0.0078125  0.359375  ]
#  [0.34532374 0.08633094 0.00719424 0.46043165 0.10071942]
#  [0.05031447 0.05031447 0.16352201 0.         0.73584906]]

# %% [markdown]
# **Plot Evaluation**

# %%
model.save("07_model.h5")

# %%
def plot_example(X, y, y_pred=None):
# Create figure with 3 x 3 sub-plots.
  fig, axes = plt.subplots(3, 6)
  fig.set_size_inches(18,10)
  fig.subplots_adjust(hspace=0.3, wspace=0.3)
  X, y = X[:18, ..., 0], y[:18]
  for i, ax in enumerate(axes.flat):
    # Plot image.
    ax.imshow(X[i], alpha = 1)
    # Show true and predicted classes.
    if y_pred is None:
      xlabel = "True: {0}".format(y[i])
    else:
      xlabel = "True: {0}, Pred: {1}".format(y[i], y_pred[i])
    # Show the classes as the label on the x-axis.
    ax.set_xlabel(xlabel)
    # Remove ticks from the plot.
    ax.set_xticks([])
    ax.set_yticks([])
    # Ensure the plot is shown correctly with multiple plots in a single Notebook cell.
  plt.show()

# %%
model = tf.keras.models.load_model('07_model.h5')
#%matplotlib inline
# Make prediction
predictions = model.predict(x_test)
# retrieve prediction indices
pred_y = np.argmax(predictions, axis=1)
# Plot some examples with model predictions
plot_example(x_test, y_test, y_pred)
