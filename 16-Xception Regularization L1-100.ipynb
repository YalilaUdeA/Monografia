# %% [markdown]
# # Flower Classification
#
# **Exploracion de datos y Preprocesamiento**
#
# **Yalila Aljure Jimenez**
#
# email: yalila.aljure@udea.edu.co
#
# CC. 5288540

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.6.0'

# %%
import keras
keras.__version__
# Out:
# '2.6.0'

# %%
import sklearn
sklearn.__version__
# Out:
# '0.22.2.post1'

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import PIL
import pathlib
from mpl_toolkits.axes_grid1 import ImageGrid
from matplotlib import pyplot as plt
import random
import math 
from sklearn.metrics import roc_curve, auc, multilabel_confusion_matrix, plot_confusion_matrix, roc_auc_score
from keras.layers import Conv2D, Dropout, MaxPooling2D, BatchNormalization, Activation, Flatten, Dense, InputLayer, Input, SeparableConv2D, ReLU, GlobalAvgPool2D,MaxPool2D,Add
from keras.models import Sequential, Model
from keras import regularizers
from tensorflow.keras import regularizers, optimizers
from keras.models import Sequential, Model
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
import tensorflow.keras.backend as K

# %% [markdown]
# **LOAD DATA**

# %%
# !wget https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# Out:
# --2021-10-28 18:51:30--  https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.71.128, 74.125.133.128, 74.125.140.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.71.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 228813984 (218M) [application/x-compressed-tar]
# Saving to: ‘flower_photos.tgz’
#
# flower_photos.tgz   100%[===================>] 218.21M  74.6MB/s    in 2.9s
#
# 2021-10-28 18:51:33 (74.6 MB/s) - ‘flower_photos.tgz’ saved [228813984/228813984]

# %%
# Unzipping Data
# !gunzip flower_photos.tgz

# %%
# !tar -xvf flower_photos.tar

# %% [markdown]
# **Plotting Images**

# %%
data_dir = pathlib.Path('flower_photos')
folder = list(data_dir.glob('*'))
images = list(data_dir.glob('*/*.jpg')) #list of all images (full path)

# %%
len(images) # Number of images
# Out:
# 3670

# %%
fig = plt.figure(figsize=(20, 20))
iterable = np.array(random.sample(range(1, 3670), 54)) # Choosing 54 random images
for i in range(54):
    plt.subplot(9, 6, i+1)
    j = iterable[i]
    plt.title(str(images[j]).split('/')[-1], fontsize=10) # file name and disply as title
    plt.imshow(PIL.Image.open(images[j])) # Displaying Image
    ax = plt.axis("off")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Parameters**

# %%
image_size = 224 # Setting the size of the images
b_size = 32

# %% [markdown]
# **Imagen Preprocessing**
#
# Data Augmantation

# %% [markdown]
# Original source is not partitioned. The test set will be fixed at 20% of the entire dataset. The rest of the dataset will be used for training (0.8) and validation (0.2).

# %%
idg_flip = tf.keras.preprocessing.image.ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest',
    validation_split = 0.2
)

# %%
flower_gen_train = idg_flip.flow_from_directory(data_dir,
                                    target_size=(image_size, image_size),
                                    batch_size=b_size,
                                    subset='training',
                                    class_mode='categorical',
                                    shuffle=True,
                                    seed=123
                                    )
# Out:
# Found 2939 images belonging to 5 classes.

# %%
flower_gen_test = idg_flip.flow_from_directory(data_dir,
                                    target_size=(image_size, image_size),
                                    batch_size=b_size,
                                    subset='validation',
                                    class_mode='categorical',
                                    shuffle=True,
                                    seed=123
                                    )
# Out:
# Found 731 images belonging to 5 classes.

# %% [markdown]
# **Xception**

# %%
# creating the Conv-Batch Norm block

def conv_bn(x, filters, kernel_size, strides=1):
  x = Conv2D(filters=filters, 
               kernel_size = kernel_size, 
               strides=strides, 
               padding = 'same', 
               kernel_regularizer=regularizers.l1(0.01),
               use_bias = False)(x)
  x = BatchNormalization()(x)
  return x

# %%
# creating separableConv-Batch Norm block

def sep_bn(x, filters, kernel_size, strides=1):
    x = SeparableConv2D(filters=filters, 
                        kernel_size = kernel_size, 
                        strides=strides, 
                        padding = 'same', 
                        kernel_regularizer=regularizers.l1(0.01),
                        use_bias = False)(x)
    x = BatchNormalization()(x)
    return x

# %%
# entry flow

def entry_flow(x):
    
    x = conv_bn(x, filters =32, kernel_size =3, strides=2)
    x = ReLU()(x)
    x = conv_bn(x, filters =64, kernel_size =3, strides=1)
    tensor = ReLU()(x)
    
    x = sep_bn(tensor, filters = 128, kernel_size =3)
    x = ReLU()(x)
    x = sep_bn(x, filters = 128, kernel_size =3)
    x = MaxPool2D(pool_size=3, strides=2, padding = 'same')(x)
    
    tensor = conv_bn(tensor, filters=128, kernel_size = 1,strides=2)
    x = Add()([tensor,x])
    
    x = ReLU()(x)
    x = sep_bn(x, filters =256, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters =256, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding = 'same')(x)
    
    tensor = conv_bn(tensor, filters=256, kernel_size = 1,strides=2)
    x = Add()([tensor,x])
    
    x = ReLU()(x)
    x = sep_bn(x, filters =728, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters =728, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding = 'same')(x)
    
    tensor = conv_bn(tensor, filters=728, kernel_size = 1,strides=2)
    x = Add()([tensor,x])
    return x

# %%
# middle flow

def middle_flow(tensor):
    
    for _ in range(8):
        x = ReLU()(tensor)
        x = sep_bn(x, filters = 728, kernel_size = 3)
        x = ReLU()(x)
        x = sep_bn(x, filters = 728, kernel_size = 3)
        x = ReLU()(x)
        x = sep_bn(x, filters = 728, kernel_size = 3)
        x = ReLU()(x)
        tensor = Add()([tensor,x])
        
    return tensor

# %%
# exit flow

def exit_flow(tensor):
    
    
    x = ReLU()(tensor)
   
    x = sep_bn(x, filters = 728,  kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters = 1024,  kernel_size=3)
    x = MaxPool2D(pool_size = 3, strides = 2, padding ='same')(x)
    tensor = conv_bn(tensor, filters =1024, kernel_size=1, strides =2)
    x = Add()([tensor,x])
    
    x = sep_bn(x, filters = 1536,  kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters = 2048,  kernel_size=3)
    x = GlobalAvgPool2D()(x)
    
    

    x = Dense (units = 5, activation = 'softmax')(x)
    
    return x

# %%
input = Input(shape = (image_size,image_size,3))
x = entry_flow(input)
x = middle_flow(x)
output = exit_flow(x)

model = Model (inputs=input, outputs=output)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 112, 112, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 112, 112, 64) 18432       re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 112, 112, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 112, 112, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 112, 112, 128 8768        re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 112, 112, 128 512         separable_conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 112, 112, 128 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 112, 112, 128 17536       re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 128)  8192        re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 112, 112, 128 512         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 128)  0           batch_normalization_4[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 56, 56, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 56, 56, 256)  33920       re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 256)  1024        separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 56, 56, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 56, 56, 256)  67840       re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 256)  32768       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 256)  1024        separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 28, 28, 256)  0           batch_normalization_7[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 28, 28, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 28, 28, 728)  188672      re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 728)  2912        separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 28, 28, 728)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 28, 28, 728)  536536      re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 14, 14, 728)  186368      batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 28, 28, 728)  2912        separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 14, 14, 728)  2912        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 728)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14, 14, 728)  0           batch_normalization_10[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 14, 14, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 14, 14, 728)  536536      re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 14, 14, 728)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 14, 14, 728)  536536      re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 14, 14, 728)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_8 (SeparableCo (None, 14, 14, 728)  536536      re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_8[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 14, 14, 728)  0           add_2[0][0]
#                                                                  re_lu_10[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 14, 14, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_9 (SeparableCo (None, 14, 14, 728)  536536      re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_9[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_10 (SeparableC (None, 14, 14, 728)  536536      re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_10[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_11 (SeparableC (None, 14, 14, 728)  536536      re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_11[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 14, 14, 728)  0           add_3[0][0]
#                                                                  re_lu_14[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 14, 14, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_12 (SeparableC (None, 14, 14, 728)  536536      re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_12[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_13 (SeparableC (None, 14, 14, 728)  536536      re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_13[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_14 (SeparableC (None, 14, 14, 728)  536536      re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_14[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 14, 14, 728)  0           add_4[0][0]
#                                                                  re_lu_18[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 14, 14, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_15 (SeparableC (None, 14, 14, 728)  536536      re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_15[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_16 (SeparableC (None, 14, 14, 728)  536536      re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_16[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_17 (SeparableC (None, 14, 14, 728)  536536      re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_17[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 14, 14, 728)  0           add_5[0][0]
#                                                                  re_lu_22[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 14, 14, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_18 (SeparableC (None, 14, 14, 728)  536536      re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_18[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_19 (SeparableC (None, 14, 14, 728)  536536      re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_19[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_20 (SeparableC (None, 14, 14, 728)  536536      re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_20[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 14, 14, 728)  0           add_6[0][0]
#                                                                  re_lu_26[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 14, 14, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_21 (SeparableC (None, 14, 14, 728)  536536      re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_21[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_22 (SeparableC (None, 14, 14, 728)  536536      re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_22[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_23 (SeparableC (None, 14, 14, 728)  536536      re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_23[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 728)  0           add_7[0][0]
#                                                                  re_lu_30[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 14, 14, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_24 (SeparableC (None, 14, 14, 728)  536536      re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_24[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_25 (SeparableC (None, 14, 14, 728)  536536      re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_25[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_26 (SeparableC (None, 14, 14, 728)  536536      re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_26[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 728)  0           add_8[0][0]
#                                                                  re_lu_34[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, 14, 14, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_27 (SeparableC (None, 14, 14, 728)  536536      re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_27[0][0]
# __________________________________________________________________________________________________
# re_lu_36 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_28 (SeparableC (None, 14, 14, 728)  536536      re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_28[0][0]
# __________________________________________________________________________________________________
# re_lu_37 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_29 (SeparableC (None, 14, 14, 728)  536536      re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_29[0][0]
# __________________________________________________________________________________________________
# re_lu_38 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 728)  0           add_9[0][0]
#                                                                  re_lu_38[0][0]
# __________________________________________________________________________________________________
# re_lu_39 (ReLU)                 (None, 14, 14, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_30 (SeparableC (None, 14, 14, 728)  536536      re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 14, 14, 728)  2912        separable_conv2d_30[0][0]
# __________________________________________________________________________________________________
# re_lu_40 (ReLU)                 (None, 14, 14, 728)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_31 (SeparableC (None, 14, 14, 1024) 752024      re_lu_40[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 7, 7, 1024)   745472      add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 14, 14, 1024) 4096        separable_conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 7, 7, 1024)   4096        conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 1024)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 7, 7, 1024)   0           batch_normalization_37[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_32 (SeparableC (None, 7, 7, 1536)   1582080     add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 7, 7, 1536)   6144        separable_conv2d_32[0][0]
# __________________________________________________________________________________________________
# re_lu_41 (ReLU)                 (None, 7, 7, 1536)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_33 (SeparableC (None, 7, 7, 2048)   3159552     re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 7, 7, 2048)   8192        separable_conv2d_33[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 5)            10245       global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 20,871,725
# Trainable params: 20,817,197
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy','Precision','Recall'])

# %%
Result = model.fit(flower_gen_train, validation_data=flower_gen_test
                   , epochs=100, verbose=1, shuffle=True)
# Out:
# Epoch 1/100
# 92/92 [==============================] - 170s 1s/step - loss: 285.0581 - accuracy: 0.5393 - precision: 0.6729 - recall: 0.3331 - val_loss: 243.8242 - val_accuracy: 0.2175 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 92/92 [==============================] - 129s 1s/step - loss: 206.8708 - accuracy: 0.6118 - precision: 0.7087 - recall: 0.4760 - val_loss: 172.5399 - val_accuracy: 0.2175 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 92/92 [==============================] - 129s 1s/step - loss: 142.0907 - accuracy: 0.6264 - precision: 0.7196 - recall: 0.5179 - val_loss: 114.5700 - val_accuracy: 0.2175 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/100
# 92/92 [==============================] - 129s 1s/step - loss: 90.6798 - accuracy: 0.6455 - precision: 0.7302 - recall: 0.5332 - val_loss: 69.8695 - val_accuracy: 0.2449 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/100
# 92/92 [==============================] - 129s 1s/step - loss: 52.5088 - accuracy: 0.6543 - precision: 0.7344 - recall: 0.5550 - val_loss: 38.6256 - val_accuracy: 0.2449 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/100
# 92/92 [==============================] - 128s 1s/step - loss: 27.8013 - accuracy: 0.6295 - precision: 0.7098 - recall: 0.5260 - val_loss: 20.8202 - val_accuracy: 0.2449 - val_precision: 0.2452 - val_recall: 0.2449
# Epoch 7/100
# 92/92 [==============================] - 129s 1s/step - loss: 15.9472 - accuracy: 0.6002 - precision: 0.6894 - recall: 0.4893 - val_loss: 13.5101 - val_accuracy: 0.2449 - val_precision: 0.2472 - val_recall: 0.2449
# Epoch 8/100
# 92/92 [==============================] - 128s 1s/step - loss: 10.4929 - accuracy: 0.5978 - precision: 0.6842 - recall: 0.4740 - val_loss: 9.8626 - val_accuracy: 0.2449 - val_precision: 0.2472 - val_recall: 0.2449
# Epoch 9/100
# 92/92 [==============================] - 128s 1s/step - loss: 7.6923 - accuracy: 0.5699 - precision: 0.6502 - recall: 0.4389 - val_loss: 7.4592 - val_accuracy: 0.2736 - val_precision: 0.2855 - val_recall: 0.2339
# Epoch 10/100
# 92/92 [==============================] - 129s 1s/step - loss: 6.0003 - accuracy: 0.5934 - precision: 0.6885 - recall: 0.4587 - val_loss: 5.5276 - val_accuracy: 0.4665 - val_precision: 0.6027 - val_recall: 0.3092
# Epoch 11/100
# 92/92 [==============================] - 128s 1s/step - loss: 4.7304 - accuracy: 0.6077 - precision: 0.6791 - recall: 0.4825 - val_loss: 4.4459 - val_accuracy: 0.4610 - val_precision: 0.5223 - val_recall: 0.3844
# Epoch 12/100
# 92/92 [==============================] - 129s 1s/step - loss: 3.7343 - accuracy: 0.6155 - precision: 0.6934 - recall: 0.4832 - val_loss: 3.8005 - val_accuracy: 0.3940 - val_precision: 0.4268 - val_recall: 0.3311
# Epoch 13/100
# 92/92 [==============================] - 128s 1s/step - loss: 3.0531 - accuracy: 0.6111 - precision: 0.6969 - recall: 0.4944 - val_loss: 3.2799 - val_accuracy: 0.4159 - val_precision: 0.4439 - val_recall: 0.3461
# Epoch 14/100
# 92/92 [==============================] - 128s 1s/step - loss: 2.5798 - accuracy: 0.6264 - precision: 0.7111 - recall: 0.5151 - val_loss: 2.4294 - val_accuracy: 0.5677 - val_precision: 0.6516 - val_recall: 0.4733
# Epoch 15/100
# 92/92 [==============================] - 128s 1s/step - loss: 2.3003 - accuracy: 0.6366 - precision: 0.7226 - recall: 0.5352 - val_loss: 3.0419 - val_accuracy: 0.3981 - val_precision: 0.4392 - val_recall: 0.3311
# Epoch 16/100
# 92/92 [==============================] - 128s 1s/step - loss: 2.0870 - accuracy: 0.6461 - precision: 0.7163 - recall: 0.5464 - val_loss: 2.2311 - val_accuracy: 0.5445 - val_precision: 0.6177 - val_recall: 0.4487
# Epoch 17/100
# 92/92 [==============================] - 128s 1s/step - loss: 1.9499 - accuracy: 0.6431 - precision: 0.7190 - recall: 0.5390 - val_loss: 2.3801 - val_accuracy: 0.5677 - val_precision: 0.5990 - val_recall: 0.5007
# Epoch 18/100
# 92/92 [==============================] - 128s 1s/step - loss: 1.7902 - accuracy: 0.6512 - precision: 0.7219 - recall: 0.5573 - val_loss: 2.3263 - val_accuracy: 0.4610 - val_precision: 0.5602 - val_recall: 0.3817
# Epoch 19/100
# 92/92 [==============================] - 128s 1s/step - loss: 1.6858 - accuracy: 0.6778 - precision: 0.7462 - recall: 0.5842 - val_loss: 1.7452 - val_accuracy: 0.6662 - val_precision: 0.7242 - val_recall: 0.5568
# Epoch 20/100
# 92/92 [==============================] - 128s 1s/step - loss: 1.6823 - accuracy: 0.6754 - precision: 0.7429 - recall: 0.5812 - val_loss: 2.1146 - val_accuracy: 0.5828 - val_precision: 0.6510 - val_recall: 0.5130
# Epoch 21/100
# 92/92 [==============================] - 128s 1s/step - loss: 1.6452 - accuracy: 0.6883 - precision: 0.7507 - recall: 0.5975 - val_loss: 2.6344 - val_accuracy: 0.3735 - val_precision: 0.3716 - val_recall: 0.2969
# Epoch 22/100
# 92/92 [==============================] - 128s 1s/step - loss: 1.6230 - accuracy: 0.6839 - precision: 0.7497 - recall: 0.6002 - val_loss: 2.8017 - val_accuracy: 0.4706 - val_precision: 0.4779 - val_recall: 0.4432
# Epoch 23/100
# 92/92 [==============================] - 128s 1s/step - loss: 1.6069 - accuracy: 0.6890 - precision: 0.7689 - recall: 0.6135 - val_loss: 1.7368 - val_accuracy: 0.6689 - val_precision: 0.7053 - val_recall: 0.6416
# Epoch 24/100
# 92/92 [==============================] - 128s 1s/step - loss: 1.6396 - accuracy: 0.6887 - precision: 0.7614 - recall: 0.6080 - val_loss: 1.8861 - val_accuracy: 0.5828 - val_precision: 0.6334 - val_recall: 0.5390
# Epoch 25/100
# 92/92 [==============================] - 128s 1s/step - loss: 1.5982 - accuracy: 0.6968 - precision: 0.7646 - recall: 0.6135 - val_loss: 2.1903 - val_accuracy: 0.5349 - val_precision: 0.5806 - val_recall: 0.4337
# Epoch 26/100
# 92/92 [==============================] - 128s 1s/step - loss: 1.5896 - accuracy: 0.7060 - precision: 0.7758 - recall: 0.6227 - val_loss: 2.3040 - val_accuracy: 0.5253 - val_precision: 0.5887 - val_recall: 0.4542
# Epoch 27/100
# 92/92 [==============================] - 128s 1s/step - loss: 1.5935 - accuracy: 0.7224 - precision: 0.7941 - recall: 0.6458 - val_loss: 2.1997 - val_accuracy: 0.5581 - val_precision: 0.6093 - val_recall: 0.4843
# Epoch 28/100
# 92/92 [==============================] - 128s 1s/step - loss: 1.5643 - accuracy: 0.7173 - precision: 0.7862 - recall: 0.6417 - val_loss: 1.5697 - val_accuracy: 0.6594 - val_precision: 0.7405 - val_recall: 0.5896
# Epoch 29/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.5776 - accuracy: 0.7125 - precision: 0.7845 - recall: 0.6417 - val_loss: 2.4359 - val_accuracy: 0.5404 - val_precision: 0.6192 - val_recall: 0.4938
# Epoch 30/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.5450 - accuracy: 0.7332 - precision: 0.7984 - recall: 0.6632 - val_loss: 1.6122 - val_accuracy: 0.6908 - val_precision: 0.7353 - val_recall: 0.6498
# Epoch 31/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.4923 - accuracy: 0.7373 - precision: 0.8009 - recall: 0.6706 - val_loss: 2.0214 - val_accuracy: 0.5075 - val_precision: 0.5598 - val_recall: 0.4419
# Epoch 32/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.6133 - accuracy: 0.7138 - precision: 0.7810 - recall: 0.6444 - val_loss: 2.4519 - val_accuracy: 0.5335 - val_precision: 0.5881 - val_recall: 0.4884
# Epoch 33/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.4905 - accuracy: 0.7499 - precision: 0.8136 - recall: 0.6802 - val_loss: 1.5861 - val_accuracy: 0.6744 - val_precision: 0.7341 - val_recall: 0.6306
# Epoch 34/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.5203 - accuracy: 0.7349 - precision: 0.7958 - recall: 0.6751 - val_loss: 1.5119 - val_accuracy: 0.7100 - val_precision: 0.7626 - val_recall: 0.6416
# Epoch 35/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.4970 - accuracy: 0.7417 - precision: 0.7954 - recall: 0.6774 - val_loss: 1.9215 - val_accuracy: 0.6183 - val_precision: 0.6801 - val_recall: 0.5759
# Epoch 36/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.4653 - accuracy: 0.7598 - precision: 0.8154 - recall: 0.6958 - val_loss: 2.1557 - val_accuracy: 0.5663 - val_precision: 0.6096 - val_recall: 0.5363
# Epoch 37/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.4460 - accuracy: 0.7686 - precision: 0.8216 - recall: 0.7081 - val_loss: 1.7716 - val_accuracy: 0.6375 - val_precision: 0.7003 - val_recall: 0.5787
# Epoch 38/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.4927 - accuracy: 0.7622 - precision: 0.8104 - recall: 0.7023 - val_loss: 2.1329 - val_accuracy: 0.5554 - val_precision: 0.5948 - val_recall: 0.5280
# Epoch 39/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.4538 - accuracy: 0.7577 - precision: 0.8206 - recall: 0.7064 - val_loss: 2.0796 - val_accuracy: 0.6088 - val_precision: 0.6511 - val_recall: 0.5718
# Epoch 40/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.4547 - accuracy: 0.7679 - precision: 0.8219 - recall: 0.7145 - val_loss: 2.2258 - val_accuracy: 0.5554 - val_precision: 0.6168 - val_recall: 0.4911
# Epoch 41/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.4512 - accuracy: 0.7625 - precision: 0.8099 - recall: 0.7074 - val_loss: 1.5498 - val_accuracy: 0.6977 - val_precision: 0.7683 - val_recall: 0.6306
# Epoch 42/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.4453 - accuracy: 0.7720 - precision: 0.8235 - recall: 0.7142 - val_loss: 1.8173 - val_accuracy: 0.6648 - val_precision: 0.7202 - val_recall: 0.6197
# Epoch 43/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.3953 - accuracy: 0.7816 - precision: 0.8304 - recall: 0.7298 - val_loss: 2.6067 - val_accuracy: 0.5691 - val_precision: 0.6084 - val_recall: 0.5335
# Epoch 44/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.5144 - accuracy: 0.7700 - precision: 0.8117 - recall: 0.7173 - val_loss: 1.7756 - val_accuracy: 0.6785 - val_precision: 0.7074 - val_recall: 0.6416
# Epoch 45/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.3781 - accuracy: 0.7850 - precision: 0.8294 - recall: 0.7346 - val_loss: 2.7127 - val_accuracy: 0.5445 - val_precision: 0.5697 - val_recall: 0.5089
# Epoch 46/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.3951 - accuracy: 0.7850 - precision: 0.8349 - recall: 0.7435 - val_loss: 2.4061 - val_accuracy: 0.4993 - val_precision: 0.5422 - val_recall: 0.4131
# Epoch 47/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.3930 - accuracy: 0.7805 - precision: 0.8308 - recall: 0.7353 - val_loss: 1.7275 - val_accuracy: 0.6416 - val_precision: 0.7301 - val_recall: 0.5882
# Epoch 48/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.4376 - accuracy: 0.7884 - precision: 0.8364 - recall: 0.7445 - val_loss: 3.4547 - val_accuracy: 0.4856 - val_precision: 0.4940 - val_recall: 0.4542
# Epoch 49/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.3837 - accuracy: 0.7850 - precision: 0.8329 - recall: 0.7377 - val_loss: 2.3158 - val_accuracy: 0.6074 - val_precision: 0.6475 - val_recall: 0.5705
# Epoch 50/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.4172 - accuracy: 0.7907 - precision: 0.8415 - recall: 0.7516 - val_loss: 1.4664 - val_accuracy: 0.7291 - val_precision: 0.7729 - val_recall: 0.6799
# Epoch 51/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.3388 - accuracy: 0.7914 - precision: 0.8375 - recall: 0.7591 - val_loss: 2.2733 - val_accuracy: 0.5568 - val_precision: 0.6031 - val_recall: 0.5363
# Epoch 52/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.2864 - accuracy: 0.8118 - precision: 0.8509 - recall: 0.7731 - val_loss: 1.9600 - val_accuracy: 0.5964 - val_precision: 0.6740 - val_recall: 0.5007
# Epoch 53/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.3089 - accuracy: 0.8118 - precision: 0.8525 - recall: 0.7748 - val_loss: 1.8461 - val_accuracy: 0.6361 - val_precision: 0.6869 - val_recall: 0.6033
# Epoch 54/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.3458 - accuracy: 0.8135 - precision: 0.8553 - recall: 0.7700 - val_loss: 1.7632 - val_accuracy: 0.6936 - val_precision: 0.7329 - val_recall: 0.6457
# Epoch 55/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.4037 - accuracy: 0.8078 - precision: 0.8473 - recall: 0.7625 - val_loss: 3.7130 - val_accuracy: 0.4679 - val_precision: 0.4801 - val_recall: 0.4295
# Epoch 56/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.3194 - accuracy: 0.8186 - precision: 0.8581 - recall: 0.7819 - val_loss: 2.9219 - val_accuracy: 0.4282 - val_precision: 0.4366 - val_recall: 0.3912
# Epoch 57/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.2706 - accuracy: 0.8241 - precision: 0.8607 - recall: 0.7904 - val_loss: 1.9490 - val_accuracy: 0.6224 - val_precision: 0.6447 - val_recall: 0.6033
# Epoch 58/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.3578 - accuracy: 0.8115 - precision: 0.8553 - recall: 0.7785 - val_loss: 2.7484 - val_accuracy: 0.6142 - val_precision: 0.6230 - val_recall: 0.5855
# Epoch 59/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.5364 - accuracy: 0.8037 - precision: 0.8479 - recall: 0.7608 - val_loss: 1.7589 - val_accuracy: 0.6744 - val_precision: 0.7571 - val_recall: 0.6183
# Epoch 60/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.2638 - accuracy: 0.8336 - precision: 0.8656 - recall: 0.7952 - val_loss: 16.9548 - val_accuracy: 0.2955 - val_precision: 0.2982 - val_recall: 0.2941
# Epoch 61/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.3398 - accuracy: 0.8203 - precision: 0.8550 - recall: 0.7826 - val_loss: 1.6702 - val_accuracy: 0.7073 - val_precision: 0.7547 - val_recall: 0.6525
# Epoch 62/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.2652 - accuracy: 0.8275 - precision: 0.8624 - recall: 0.7952 - val_loss: 2.4447 - val_accuracy: 0.6019 - val_precision: 0.6304 - val_recall: 0.5787
# Epoch 63/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.2403 - accuracy: 0.8367 - precision: 0.8688 - recall: 0.8044 - val_loss: 1.8728 - val_accuracy: 0.6813 - val_precision: 0.7247 - val_recall: 0.6553
# Epoch 64/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.2577 - accuracy: 0.8312 - precision: 0.8629 - recall: 0.7989 - val_loss: 1.7213 - val_accuracy: 0.7059 - val_precision: 0.7342 - val_recall: 0.6689
# Epoch 65/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.2718 - accuracy: 0.8316 - precision: 0.8632 - recall: 0.7989 - val_loss: 1.5395 - val_accuracy: 0.7018 - val_precision: 0.7430 - val_recall: 0.6566
# Epoch 66/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.2041 - accuracy: 0.8418 - precision: 0.8762 - recall: 0.8142 - val_loss: 1.7821 - val_accuracy: 0.6375 - val_precision: 0.6979 - val_recall: 0.5910
# Epoch 67/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.3745 - accuracy: 0.8258 - precision: 0.8589 - recall: 0.7931 - val_loss: 2.1160 - val_accuracy: 0.6252 - val_precision: 0.6530 - val_recall: 0.5896
# Epoch 68/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.1777 - accuracy: 0.8489 - precision: 0.8822 - recall: 0.8234 - val_loss: 2.1663 - val_accuracy: 0.6334 - val_precision: 0.6692 - val_recall: 0.5978
# Epoch 69/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.2028 - accuracy: 0.8496 - precision: 0.8803 - recall: 0.8159 - val_loss: 1.6943 - val_accuracy: 0.7100 - val_precision: 0.7300 - val_recall: 0.6881
# Epoch 70/100
# 92/92 [==============================] - 131s 1s/step - loss: 1.2193 - accuracy: 0.8469 - precision: 0.8780 - recall: 0.8227 - val_loss: 1.5421 - val_accuracy: 0.7141 - val_precision: 0.7358 - val_recall: 0.6895
# Epoch 71/100
# 92/92 [==============================] - 130s 1s/step - loss: 1.2184 - accuracy: 0.8557 - precision: 0.8827 - recall: 0.8295 - val_loss: 2.0411 - val_accuracy: 0.5855 - val_precision: 0.6119 - val_recall: 0.5609
# Epoch 72/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.1695 - accuracy: 0.8557 - precision: 0.8807 - recall: 0.8340 - val_loss: 2.1432 - val_accuracy: 0.6211 - val_precision: 0.6317 - val_recall: 0.6101
# Epoch 73/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.1991 - accuracy: 0.8561 - precision: 0.8796 - recall: 0.8278 - val_loss: 1.7837 - val_accuracy: 0.6826 - val_precision: 0.7036 - val_recall: 0.6430
# Epoch 74/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.1390 - accuracy: 0.8673 - precision: 0.8903 - recall: 0.8452 - val_loss: 1.7853 - val_accuracy: 0.6922 - val_precision: 0.7120 - val_recall: 0.6594
# Epoch 75/100
# 92/92 [==============================] - 130s 1s/step - loss: 1.1439 - accuracy: 0.8612 - precision: 0.8872 - recall: 0.8350 - val_loss: 1.6918 - val_accuracy: 0.6881 - val_precision: 0.7141 - val_recall: 0.6662
# Epoch 76/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.2488 - accuracy: 0.8448 - precision: 0.8722 - recall: 0.8220 - val_loss: 1.9935 - val_accuracy: 0.6553 - val_precision: 0.6745 - val_recall: 0.6320
# Epoch 77/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.1438 - accuracy: 0.8653 - precision: 0.8942 - recall: 0.8428 - val_loss: 1.4695 - val_accuracy: 0.7250 - val_precision: 0.7585 - val_recall: 0.7004
# Epoch 78/100
# 92/92 [==============================] - 130s 1s/step - loss: 1.2023 - accuracy: 0.8636 - precision: 0.8863 - recall: 0.8408 - val_loss: 4.4441 - val_accuracy: 0.5855 - val_precision: 0.5968 - val_recall: 0.5650
# Epoch 79/100
# 92/92 [==============================] - 130s 1s/step - loss: 1.1543 - accuracy: 0.8632 - precision: 0.8852 - recall: 0.8445 - val_loss: 1.5723 - val_accuracy: 0.7360 - val_precision: 0.7617 - val_recall: 0.7127
# Epoch 80/100
# 92/92 [==============================] - 130s 1s/step - loss: 1.4721 - accuracy: 0.8384 - precision: 0.8686 - recall: 0.8163 - val_loss: 9.9368 - val_accuracy: 0.3611 - val_precision: 0.3635 - val_recall: 0.3516
# Epoch 81/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.4971 - accuracy: 0.8452 - precision: 0.8776 - recall: 0.8197 - val_loss: 1.9957 - val_accuracy: 0.6156 - val_precision: 0.6716 - val_recall: 0.5595
# Epoch 82/100
# 92/92 [==============================] - 130s 1s/step - loss: 1.0857 - accuracy: 0.8768 - precision: 0.8968 - recall: 0.8574 - val_loss: 2.3629 - val_accuracy: 0.5978 - val_precision: 0.6101 - val_recall: 0.5800
# Epoch 83/100
# 92/92 [==============================] - 130s 1s/step - loss: 1.0651 - accuracy: 0.8870 - precision: 0.9103 - recall: 0.8697 - val_loss: 1.8369 - val_accuracy: 0.6990 - val_precision: 0.7209 - val_recall: 0.6785
# Epoch 84/100
# 92/92 [==============================] - 130s 1s/step - loss: 1.3884 - accuracy: 0.8493 - precision: 0.8753 - recall: 0.8285 - val_loss: 3.4628 - val_accuracy: 0.5937 - val_precision: 0.6115 - val_recall: 0.5814
# Epoch 85/100
# 92/92 [==============================] - 130s 1s/step - loss: 1.1373 - accuracy: 0.8687 - precision: 0.8923 - recall: 0.8510 - val_loss: 1.6367 - val_accuracy: 0.7332 - val_precision: 0.7471 - val_recall: 0.7155
# Epoch 86/100
# 92/92 [==============================] - 130s 1s/step - loss: 1.0816 - accuracy: 0.8785 - precision: 0.8990 - recall: 0.8602 - val_loss: 1.6092 - val_accuracy: 0.6936 - val_precision: 0.7308 - val_recall: 0.6758
# Epoch 87/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.0168 - accuracy: 0.8932 - precision: 0.9066 - recall: 0.8789 - val_loss: 1.7526 - val_accuracy: 0.7141 - val_precision: 0.7335 - val_recall: 0.7004
# Epoch 88/100
# 92/92 [==============================] - 130s 1s/step - loss: 1.0950 - accuracy: 0.8819 - precision: 0.8984 - recall: 0.8670 - val_loss: 2.3402 - val_accuracy: 0.6088 - val_precision: 0.6252 - val_recall: 0.5841
# Epoch 89/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.3081 - accuracy: 0.8595 - precision: 0.8807 - recall: 0.8418 - val_loss: 13.9478 - val_accuracy: 0.2695 - val_precision: 0.2672 - val_recall: 0.2654
# Epoch 90/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.1004 - accuracy: 0.8765 - precision: 0.9010 - recall: 0.8574 - val_loss: 1.5129 - val_accuracy: 0.7100 - val_precision: 0.7478 - val_recall: 0.6854
# Epoch 91/100
# 92/92 [==============================] - 130s 1s/step - loss: 1.0010 - accuracy: 0.8952 - precision: 0.9117 - recall: 0.8819 - val_loss: 1.4178 - val_accuracy: 0.7524 - val_precision: 0.7958 - val_recall: 0.7250
# Epoch 92/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.0121 - accuracy: 0.8986 - precision: 0.9142 - recall: 0.8843 - val_loss: 1.4156 - val_accuracy: 0.7688 - val_precision: 0.8026 - val_recall: 0.7620
# Epoch 93/100
# 92/92 [==============================] - 130s 1s/step - loss: 1.0760 - accuracy: 0.8853 - precision: 0.9010 - recall: 0.8697 - val_loss: 4.2926 - val_accuracy: 0.4213 - val_precision: 0.4258 - val_recall: 0.4159
# Epoch 94/100
# 92/92 [==============================] - 131s 1s/step - loss: 1.0275 - accuracy: 0.8942 - precision: 0.9123 - recall: 0.8778 - val_loss: 2.0603 - val_accuracy: 0.6553 - val_precision: 0.6778 - val_recall: 0.6361
# Epoch 95/100
# 92/92 [==============================] - 130s 1s/step - loss: 1.0614 - accuracy: 0.8918 - precision: 0.9041 - recall: 0.8761 - val_loss: 2.5040 - val_accuracy: 0.6621 - val_precision: 0.6704 - val_recall: 0.6512
# Epoch 96/100
# 92/92 [==============================] - 130s 1s/step - loss: 1.0407 - accuracy: 0.9034 - precision: 0.9170 - recall: 0.8911 - val_loss: 1.7199 - val_accuracy: 0.6936 - val_precision: 0.7236 - val_recall: 0.6840
# Epoch 97/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.0015 - accuracy: 0.9037 - precision: 0.9211 - recall: 0.8894 - val_loss: 1.6409 - val_accuracy: 0.7456 - val_precision: 0.7739 - val_recall: 0.7209
# Epoch 98/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.0704 - accuracy: 0.8989 - precision: 0.9156 - recall: 0.8826 - val_loss: 1.5529 - val_accuracy: 0.7332 - val_precision: 0.7536 - val_recall: 0.7073
# Epoch 99/100
# 92/92 [==============================] - 129s 1s/step - loss: 1.0196 - accuracy: 0.8962 - precision: 0.9109 - recall: 0.8836 - val_loss: 2.0684 - val_accuracy: 0.6142 - val_precision: 0.6287 - val_recall: 0.6047
# Epoch 100/100
# 92/92 [==============================] - 130s 1s/step - loss: 1.0142 - accuracy: 0.9034 - precision: 0.9171 - recall: 0.8918 - val_loss: 1.9869 - val_accuracy: 0.6334 - val_precision: 0.6617 - val_recall: 0.6129

# %%
mpl.rcParams.update({'font.size': 10, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})

# %%
plt.figure(figsize=(20,5))
plt.plot(Result.history['accuracy'], label='accuracy')
plt.plot(Result.history['val_accuracy'], label='val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(list(range(1,100)))
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.figure(figsize=(20,5))
plt.plot(Result.history['loss'], label='train_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(list(range(1,100)))
plt.ylim([0, 2])
plt.legend(loc='lower right')

# %%
flower_gen_test.reset()
x_test, y_test = next(flower_gen_test)
for i in tqdm(range(int(len(flower_gen_test.labels)/b_size))):
  img, label = next(flower_gen_test)
  x_test = np.append(x_test, img, axis = 0)
  y_test = np.append(y_test, label, axis = 0)

print(x_test.shape,y_test.shape)
# Out:
# 100%|██████████| 22/22 [00:10<00:00,  2.15it/s]
# (731, 224, 224, 3) (731, 5)

# %%
#plt.figure(figsize=(10,5))
y_pred = model.predict(x_test)
#y_pred = model.predict(x_test).ravel()
#fpr, tpr, thresholds = roc_curve(y_test.ravel(), y_pred)
auc_keras = roc_auc_score(y_test,y_pred,multi_class='ovr')
print("ROC AUC score OVR:" + str(auc_keras))
#plt.title("ROC AUC score:" + str(auc_keras))
#plt.plot(y_test,y_pred, marker = ".")
auc_keras = roc_auc_score(y_test,y_pred,multi_class='ovo')
print("ROC AUC score OVO:" + str(auc_keras))
# Out:
# ROC AUC score OVR:0.9108802851349708
# ROC AUC score OVO:0.9108802851349708

# %% [markdown]
# The higher the AUC, the better performance of the model at distinguishing between the positives and negatives classes

# %% [markdown]
# **Final Scores**

# %% [markdown]
# Accuracy = $\frac{(TP+TN)}{(TP+FP+TN+FN)}$
#
# Precision = $\frac{TP}{(TP+FP)}$
#
# Recall =$\frac{TP}{(TP+FN)}$

# %%
y_pred = model.predict(x_test)
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_test, axis=1)

# %%
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
flower_labels = flower_gen_train.class_indices.keys()
print(flower_labels)
# Out:
# dict_keys(['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips'])

# %%
plot_confusion_matrix(y_test, y_pred, classes=np.r_[0,1,2,3,4], normalize=True, cmap=plt.cm.PuBu)
# Out:
# Normalized confusion matrix
# [[0.46825397 0.17460317 0.11111111 0.18253968 0.06349206]
#  [0.01117318 0.61452514 0.01675978 0.31843575 0.03910615]
#  [0.0078125  0.0390625  0.4921875  0.125      0.3359375 ]
#  [0.         0.02877698 0.02158273 0.92805755 0.02158273]
#  [0.         0.05031447 0.19496855 0.12578616 0.62893082]]

# %%
model.save("07_model.h5")
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning:
#
# Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.

# %% [markdown]
# **Plot Evaluation**

# %%
def plot_example(X, y, y_pred=None):
# Create figure with 3 x 3 sub-plots.
  fig, axes = plt.subplots(3, 6)
  fig.set_size_inches(18,10)
  fig.subplots_adjust(hspace=0.3, wspace=0.3)
  X, y = X[:18, ..., 0], y[:18]
  for i, ax in enumerate(axes.flat):
    # Plot image.
    ax.imshow(X[i], alpha = 1)
    # Show true and predicted classes.
    if y_pred is None:
      xlabel = "True: {0}".format(y[i])
    else:
      xlabel = "True: {0}, Pred: {1}".format(y[i], y_pred[i])
    # Show the classes as the label on the x-axis.
    ax.set_xlabel(xlabel)
    # Remove ticks from the plot.
    ax.set_xticks([])
    ax.set_yticks([])
    # Ensure the plot is shown correctly with multiple plots in a single Notebook cell.
  plt.show()

# %%
model = tf.keras.models.load_model('07_model.h5')
#%matplotlib inline
# Make prediction
predictions = model.predict(x_test)
# retrieve prediction indices
pred_y = np.argmax(predictions, axis=1)
# Plot some examples with model predictions
plot_example(x_test, y_test, y_pred)
