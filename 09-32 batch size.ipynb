# %% [markdown]
# # Flower Classification
#
# **Exploracion de datos y Preprocesamiento**
#
# **Yalila Aljure Jimenez**
#
# email: yalila.aljure@udea.edu.co
#
# CC. 5288540

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.6.0'

# %%
import keras
keras.__version__
# Out:
# '2.6.0'

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import PIL
import pathlib
from mpl_toolkits.axes_grid1 import ImageGrid
from matplotlib import pyplot as plt
import random
import math 
from sklearn.metrics import roc_curve, auc, multilabel_confusion_matrix, plot_confusion_matrix, roc_auc_score
from keras.layers import Conv2D, Dropout, MaxPooling2D, BatchNormalization, Activation, Flatten, Dense, InputLayer, Input
from keras.models import Sequential, Model
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

# %% [markdown]
# **LOAD DATA**

# %%
# !wget https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# Out:
# --2021-10-19 21:06:35--  https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.193.128, 173.194.194.128, 173.194.196.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.193.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 228813984 (218M) [application/x-compressed-tar]
# Saving to: ‘flower_photos.tgz’
#
# flower_photos.tgz   100%[===================>] 218.21M  97.9MB/s    in 2.2s
#
# 2021-10-19 21:06:38 (97.9 MB/s) - ‘flower_photos.tgz’ saved [228813984/228813984]

# %%
# Unzipping Data
# !gunzip flower_photos.tgz

# %%
# !tar -xvf flower_photos.tar

# %% [markdown]
# **Plotting Images**

# %%
data_dir = pathlib.Path('flower_photos')
folder = list(data_dir.glob('*'))
images = list(data_dir.glob('*/*.jpg')) #list of all images (full path)

# %%
len(images) # Number of images
# Out:
# 3670

# %%
fig = plt.figure(figsize=(20, 20))
iterable = np.array(random.sample(range(1, 3670), 54)) # Choosing 54 random images
for i in range(54):
    plt.subplot(9, 6, i+1)
    j = iterable[i]
    plt.title(str(images[j]).split('/')[-1], fontsize=10) # file name and disply as title
    plt.imshow(PIL.Image.open(images[j])) # Displaying Image
    ax = plt.axis("off")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Parameters**

# %%
image_size = 224 # Setting the size of the images
b_size = 32

# %% [markdown]
# **Imagen Preprocessing**
#
# Data Augmantation

# %% [markdown]
# Original source is not partitioned. The test set will be fixed at 20% of the entire dataset. The rest of the dataset will be used for training (0.8) and validation (0.2).

# %%
idg_flip = tf.keras.preprocessing.image.ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest',
    validation_split = 0.2
)

# %%
flower_gen_train = idg_flip.flow_from_directory(data_dir,
                                    target_size=(image_size, image_size),
                                    batch_size=b_size,
                                    subset='training',
                                    class_mode='categorical',
                                    shuffle=True,
                                    seed=123
                                    )
# Out:
# Found 2939 images belonging to 5 classes.

# %%
flower_gen_test = idg_flip.flow_from_directory(data_dir,
                                    target_size=(image_size, image_size),
                                    batch_size=b_size,
                                    subset='validation',
                                    class_mode='categorical',
                                    shuffle=True,
                                    seed=123
                                    )
# Out:
# Found 731 images belonging to 5 classes.

# %% [markdown]
# **VGGNet**

# %%
# Instanciate and empty model
model = Sequential()
# First Convolutional Layer
model.add(Conv2D(64, kernel_size=(3,3), activation='PReLU',padding='same',input_shape=(image_size,image_size,3))) # 2D Convolution layer, filters = 64
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(64, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 64
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(BatchNormalization()) 
# Second Convolutional Layer
model.add(Conv2D(128, kernel_size=(3,3), activation='PReLU', padding='same')) # 2D Convolution layer, filters = 128
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(128, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 128
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(BatchNormalization()) 
# Third Convolutional Layer
model.add(Conv2D(256, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 256
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(256, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 256
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(256, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 256
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(BatchNormalization()) 
# Fourth Convolutional Layer
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(BatchNormalization()) 
# Fith convolutional layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(BatchNormalization()) 
# 1st dense layer
model.add(Flatten()) 
model.add(Dense(4096))
# Dropout
model.add(Dropout(0.5)) 
model.add(Activation('PReLU'))
# 2nd Dense Layer
model.add(Dense(4096))
# Dropout
model.add(Dropout(0.5))
# Normalization
model.add(BatchNormalization()) 
model.add(Activation('PReLU'))
# Output softmax layer
model.add(Dense(5))
model.add(Activation('softmax'))

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy','Precision','Recall'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      3213056
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      839744
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 56, 56, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 128)       475264
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 128)       247936
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 256)       345344
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 256)         602624
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 256)         592384
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1, 1, 256)         1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 1, 512)         1180672
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1, 1, 512)         2048
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1, 1, 512)         2048
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# activation (Activation)      (None, 4096)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4096)              16384
# _________________________________________________________________
# activation_1 (Activation)    (None, 4096)              4096
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 20485
# _________________________________________________________________
# activation_2 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 38,232,133
# Trainable params: 38,220,997
# Non-trainable params: 11,136
# _________________________________________________________________

# %%
Result = model.fit(flower_gen_train, validation_data=flower_gen_test
                   , epochs=100, verbose=1, shuffle=True)
# Out:
# Epoch 1/100
# 92/92 [==============================] - 99s 714ms/step - loss: 1.4951 - accuracy: 0.4226 - precision: 0.5058 - recall: 0.2691 - val_loss: 1.6084 - val_accuracy: 0.1724 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 92/92 [==============================] - 63s 686ms/step - loss: 1.2928 - accuracy: 0.5145 - precision: 0.5830 - recall: 0.4076 - val_loss: 1.6070 - val_accuracy: 0.2449 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 92/92 [==============================] - 63s 682ms/step - loss: 1.1667 - accuracy: 0.5652 - precision: 0.6259 - recall: 0.4651 - val_loss: 1.6036 - val_accuracy: 0.2449 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/100
# 92/92 [==============================] - 63s 681ms/step - loss: 1.0780 - accuracy: 0.6060 - precision: 0.6705 - recall: 0.5219 - val_loss: 1.5861 - val_accuracy: 0.1724 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/100
# 92/92 [==============================] - 63s 684ms/step - loss: 0.9922 - accuracy: 0.6342 - precision: 0.7009 - recall: 0.5567 - val_loss: 1.4590 - val_accuracy: 0.3092 - val_precision: 0.8500 - val_recall: 0.0698
# Epoch 6/100
# 92/92 [==============================] - 62s 678ms/step - loss: 0.9769 - accuracy: 0.6335 - precision: 0.7083 - recall: 0.5495 - val_loss: 1.2671 - val_accuracy: 0.5404 - val_precision: 0.8889 - val_recall: 0.0766
# Epoch 7/100
# 92/92 [==============================] - 63s 680ms/step - loss: 0.9364 - accuracy: 0.6421 - precision: 0.7200 - recall: 0.5573 - val_loss: 1.0593 - val_accuracy: 0.6375 - val_precision: 0.8161 - val_recall: 0.2914
# Epoch 8/100
# 92/92 [==============================] - 63s 682ms/step - loss: 0.8936 - accuracy: 0.6614 - precision: 0.7424 - recall: 0.5846 - val_loss: 1.0703 - val_accuracy: 0.6019 - val_precision: 0.6843 - val_recall: 0.4596
# Epoch 9/100
# 92/92 [==============================] - 63s 683ms/step - loss: 0.8780 - accuracy: 0.6652 - precision: 0.7352 - recall: 0.5914 - val_loss: 1.1101 - val_accuracy: 0.5937 - val_precision: 0.7098 - val_recall: 0.4651
# Epoch 10/100
# 92/92 [==============================] - 63s 683ms/step - loss: 0.7894 - accuracy: 0.7009 - precision: 0.7715 - recall: 0.6284 - val_loss: 0.9465 - val_accuracy: 0.6635 - val_precision: 0.7439 - val_recall: 0.5882
# Epoch 11/100
# 92/92 [==============================] - 63s 683ms/step - loss: 0.7956 - accuracy: 0.7084 - precision: 0.7634 - recall: 0.6366 - val_loss: 1.7370 - val_accuracy: 0.4870 - val_precision: 0.5271 - val_recall: 0.4528
# Epoch 12/100
# 92/92 [==============================] - 63s 682ms/step - loss: 0.7857 - accuracy: 0.6992 - precision: 0.7678 - recall: 0.6380 - val_loss: 1.0108 - val_accuracy: 0.6211 - val_precision: 0.6987 - val_recall: 0.5773
# Epoch 13/100
# 92/92 [==============================] - 63s 683ms/step - loss: 0.7840 - accuracy: 0.7040 - precision: 0.7646 - recall: 0.6366 - val_loss: 0.9327 - val_accuracy: 0.6648 - val_precision: 0.7263 - val_recall: 0.5663
# Epoch 14/100
# 92/92 [==============================] - 62s 677ms/step - loss: 0.7274 - accuracy: 0.7346 - precision: 0.7964 - recall: 0.6720 - val_loss: 1.0189 - val_accuracy: 0.6183 - val_precision: 0.6845 - val_recall: 0.5609
# Epoch 15/100
# 92/92 [==============================] - 63s 679ms/step - loss: 0.7356 - accuracy: 0.6985 - precision: 0.7679 - recall: 0.6417 - val_loss: 0.8967 - val_accuracy: 0.6648 - val_precision: 0.7500 - val_recall: 0.5581
# Epoch 16/100
# 92/92 [==============================] - 63s 680ms/step - loss: 0.7544 - accuracy: 0.7104 - precision: 0.7677 - recall: 0.6478 - val_loss: 1.0853 - val_accuracy: 0.6525 - val_precision: 0.7093 - val_recall: 0.5841
# Epoch 17/100
# 92/92 [==============================] - 63s 685ms/step - loss: 0.7339 - accuracy: 0.7183 - precision: 0.7843 - recall: 0.6557 - val_loss: 0.8403 - val_accuracy: 0.6881 - val_precision: 0.7703 - val_recall: 0.6101
# Epoch 18/100
# 92/92 [==============================] - 63s 686ms/step - loss: 0.6990 - accuracy: 0.7414 - precision: 0.8001 - recall: 0.6863 - val_loss: 0.8385 - val_accuracy: 0.7031 - val_precision: 0.7824 - val_recall: 0.6443
# Epoch 19/100
# 92/92 [==============================] - 63s 686ms/step - loss: 0.6835 - accuracy: 0.7380 - precision: 0.7974 - recall: 0.6897 - val_loss: 0.9232 - val_accuracy: 0.6799 - val_precision: 0.7274 - val_recall: 0.6170
# Epoch 56/100
# 92/92 [==============================] - 63s 682ms/step - loss: 0.4034 - accuracy: 0.8486 - precision: 0.8692 - recall: 0.8275 - val_loss: 0.6656 - val_accuracy: 0.7510 - val_precision: 0.7951 - val_recall: 0.7168
# Epoch 57/100
# 92/92 [==============================] - 63s 688ms/step - loss: 0.3635 - accuracy: 0.8619 - precision: 0.8855 - recall: 0.8394 - val_loss: 0.6898 - val_accuracy: 0.7620 - val_precision: 0.8027 - val_recall: 0.7346
# Epoch 58/100
# 92/92 [==============================] - 63s 688ms/step - loss: 0.4012 - accuracy: 0.8438 - precision: 0.8653 - recall: 0.8265 - val_loss: 0.8893 - val_accuracy: 0.7127 - val_precision: 0.7365 - val_recall: 0.6881
# Epoch 59/100
# 92/92 [==============================] - 63s 685ms/step - loss: 0.3858 - accuracy: 0.8530 - precision: 0.8768 - recall: 0.8258 - val_loss: 0.7919 - val_accuracy: 0.7415 - val_precision: 0.7791 - val_recall: 0.7141
# Epoch 60/100
# 92/92 [==============================] - 63s 685ms/step - loss: 0.3903 - accuracy: 0.8557 - precision: 0.8727 - recall: 0.8306 - val_loss: 0.7046 - val_accuracy: 0.7524 - val_precision: 0.7896 - val_recall: 0.7291
# Epoch 61/100
# 92/92 [==============================] - 63s 687ms/step - loss: 0.3878 - accuracy: 0.8537 - precision: 0.8739 - recall: 0.8326 - val_loss: 0.7402 - val_accuracy: 0.7428 - val_precision: 0.7821 - val_recall: 0.7073
# Epoch 62/100
# 92/92 [==============================] - 63s 687ms/step - loss: 0.3788 - accuracy: 0.8585 - precision: 0.8809 - recall: 0.8357 - val_loss: 0.7779 - val_accuracy: 0.7086 - val_precision: 0.7437 - val_recall: 0.6867
# Epoch 63/100
# 92/92 [==============================] - 63s 688ms/step - loss: 0.3654 - accuracy: 0.8581 - precision: 0.8828 - recall: 0.8333 - val_loss: 0.6888 - val_accuracy: 0.7606 - val_precision: 0.8034 - val_recall: 0.7209
# Epoch 64/100
# 92/92 [==============================] - 63s 686ms/step - loss: 0.3672 - accuracy: 0.8585 - precision: 0.8781 - recall: 0.8380 - val_loss: 0.7797 - val_accuracy: 0.7469 - val_precision: 0.7729 - val_recall: 0.7264
# Epoch 65/100
# 92/92 [==============================] - 63s 685ms/step - loss: 0.3708 - accuracy: 0.8663 - precision: 0.8868 - recall: 0.8479 - val_loss: 0.7420 - val_accuracy: 0.7715 - val_precision: 0.8050 - val_recall: 0.7510
# Epoch 66/100
# 92/92 [==============================] - 63s 687ms/step - loss: 0.3436 - accuracy: 0.8816 - precision: 0.8944 - recall: 0.8619 - val_loss: 0.7957 - val_accuracy: 0.7319 - val_precision: 0.7688 - val_recall: 0.7141
# Epoch 67/100
# 92/92 [==============================] - 63s 688ms/step - loss: 0.3566 - accuracy: 0.8612 - precision: 0.8802 - recall: 0.8421 - val_loss: 0.7442 - val_accuracy: 0.7592 - val_precision: 0.7850 - val_recall: 0.7442
# Epoch 68/100
# 92/92 [==============================] - 63s 688ms/step - loss: 0.3444 - accuracy: 0.8738 - precision: 0.8912 - recall: 0.8557 - val_loss: 0.7190 - val_accuracy: 0.7592 - val_precision: 0.7944 - val_recall: 0.7346
# Epoch 69/100
# 92/92 [==============================] - 64s 693ms/step - loss: 0.3302 - accuracy: 0.8727 - precision: 0.8914 - recall: 0.8578 - val_loss: 0.6805 - val_accuracy: 0.7661 - val_precision: 0.7997 - val_recall: 0.7373
# Epoch 70/100
# 92/92 [==============================] - 64s 690ms/step - loss: 0.3577 - accuracy: 0.8690 - precision: 0.8859 - recall: 0.8510 - val_loss: 0.8654 - val_accuracy: 0.7155 - val_precision: 0.7438 - val_recall: 0.6990
# Epoch 71/100
# 92/92 [==============================] - 65s 706ms/step - loss: 0.3383 - accuracy: 0.8819 - precision: 0.8985 - recall: 0.8642 - val_loss: 0.8817 - val_accuracy: 0.7223 - val_precision: 0.7593 - val_recall: 0.6990
# Epoch 72/100
# 92/92 [==============================] - 63s 689ms/step - loss: 0.3257 - accuracy: 0.8796 - precision: 0.9011 - recall: 0.8653 - val_loss: 0.7618 - val_accuracy: 0.7456 - val_precision: 0.7768 - val_recall: 0.7237
# Epoch 73/100
# 92/92 [==============================] - 63s 685ms/step - loss: 0.3267 - accuracy: 0.8796 - precision: 0.8946 - recall: 0.8636 - val_loss: 0.7896 - val_accuracy: 0.7305 - val_precision: 0.7665 - val_recall: 0.7141
# Epoch 74/100
# 92/92 [==============================] - 63s 683ms/step - loss: 0.3127 - accuracy: 0.8778 - precision: 0.8931 - recall: 0.8615 - val_loss: 0.6982 - val_accuracy: 0.7592 - val_precision: 0.7860 - val_recall: 0.7387
# Epoch 75/100
# 92/92 [==============================] - 63s 687ms/step - loss: 0.3048 - accuracy: 0.8881 - precision: 0.9030 - recall: 0.8744 - val_loss: 0.6546 - val_accuracy: 0.7770 - val_precision: 0.8142 - val_recall: 0.7551
# Epoch 76/100
# 92/92 [==============================] - 63s 686ms/step - loss: 0.3205 - accuracy: 0.8830 - precision: 0.9026 - recall: 0.8700 - val_loss: 0.7795 - val_accuracy: 0.7510 - val_precision: 0.7788 - val_recall: 0.7223
# Epoch 77/100
# 92/92 [==============================] - 63s 687ms/step - loss: 0.3155 - accuracy: 0.8823 - precision: 0.8991 - recall: 0.8673 - val_loss: 0.6803 - val_accuracy: 0.7674 - val_precision: 0.8003 - val_recall: 0.7401
# Epoch 78/100
# 92/92 [==============================] - 63s 688ms/step - loss: 0.3134 - accuracy: 0.8830 - precision: 0.9011 - recall: 0.8707 - val_loss: 0.9058 - val_accuracy: 0.7114 - val_precision: 0.7391 - val_recall: 0.6977
# Epoch 79/100
# 92/92 [==============================] - 63s 687ms/step - loss: 0.3131 - accuracy: 0.8782 - precision: 0.8937 - recall: 0.8666 - val_loss: 0.7307 - val_accuracy: 0.7360 - val_precision: 0.7814 - val_recall: 0.7141
# Epoch 80/100
# 92/92 [==============================] - 63s 685ms/step - loss: 0.2914 - accuracy: 0.8901 - precision: 0.9088 - recall: 0.8751 - val_loss: 0.9443 - val_accuracy: 0.7031 - val_precision: 0.7310 - val_recall: 0.6840
# Epoch 81/100
# 92/92 [==============================] - 64s 690ms/step - loss: 0.2981 - accuracy: 0.8809 - precision: 0.8990 - recall: 0.8663 - val_loss: 0.7970 - val_accuracy: 0.7497 - val_precision: 0.7796 - val_recall: 0.7209
# Epoch 82/100
# 92/92 [==============================] - 63s 683ms/step - loss: 0.3065 - accuracy: 0.8877 - precision: 0.9033 - recall: 0.8741 - val_loss: 0.6777 - val_accuracy: 0.7688 - val_precision: 0.8109 - val_recall: 0.7510
# Epoch 83/100
# 92/92 [==============================] - 63s 688ms/step - loss: 0.2834 - accuracy: 0.8969 - precision: 0.9103 - recall: 0.8809 - val_loss: 0.7427 - val_accuracy: 0.7538 - val_precision: 0.7871 - val_recall: 0.7332
# Epoch 84/100
# 92/92 [==============================] - 63s 687ms/step - loss: 0.2606 - accuracy: 0.9054 - precision: 0.9163 - recall: 0.8938 - val_loss: 0.8516 - val_accuracy: 0.7346 - val_precision: 0.7610 - val_recall: 0.7100
# Epoch 85/100
# 92/92 [==============================] - 63s 680ms/step - loss: 0.2619 - accuracy: 0.9075 - precision: 0.9175 - recall: 0.8962 - val_loss: 0.7823 - val_accuracy: 0.7387 - val_precision: 0.7691 - val_recall: 0.7155
# Epoch 86/100
# 92/92 [==============================] - 62s 677ms/step - loss: 0.2717 - accuracy: 0.8979 - precision: 0.9116 - recall: 0.8874 - val_loss: 0.6773 - val_accuracy: 0.7647 - val_precision: 0.8033 - val_recall: 0.7319
# Epoch 87/100
# 92/92 [==============================] - 64s 690ms/step - loss: 0.2635 - accuracy: 0.9017 - precision: 0.9157 - recall: 0.8938 - val_loss: 0.6646 - val_accuracy: 0.7798 - val_precision: 0.8142 - val_recall: 0.7551
# Epoch 88/100
# 92/92 [==============================] - 64s 694ms/step - loss: 0.2598 - accuracy: 0.9092 - precision: 0.9184 - recall: 0.9000 - val_loss: 0.8517 - val_accuracy: 0.7114 - val_precision: 0.7474 - val_recall: 0.6922
# Epoch 89/100
# 92/92 [==============================] - 64s 694ms/step - loss: 0.2693 - accuracy: 0.8986 - precision: 0.9098 - recall: 0.8850 - val_loss: 0.8148 - val_accuracy: 0.7592 - val_precision: 0.7821 - val_recall: 0.7415
# Epoch 90/100
# 92/92 [==============================] - 64s 692ms/step - loss: 0.2852 - accuracy: 0.8938 - precision: 0.9056 - recall: 0.8816 - val_loss: 0.7532 - val_accuracy: 0.7592 - val_precision: 0.7885 - val_recall: 0.7346
# Epoch 91/100
# 92/92 [==============================] - 64s 699ms/step - loss: 0.2746 - accuracy: 0.8983 - precision: 0.9114 - recall: 0.8850 - val_loss: 0.7613 - val_accuracy: 0.7565 - val_precision: 0.7759 - val_recall: 0.7387
# Epoch 92/100
# 92/92 [==============================] - 64s 698ms/step - loss: 0.2571 - accuracy: 0.9071 - precision: 0.9155 - recall: 0.8959 - val_loss: 0.7584 - val_accuracy: 0.7661 - val_precision: 0.7924 - val_recall: 0.7415
# Epoch 93/100
# 92/92 [==============================] - 63s 683ms/step - loss: 0.2682 - accuracy: 0.9030 - precision: 0.9117 - recall: 0.8918 - val_loss: 0.7017 - val_accuracy: 0.7715 - val_precision: 0.7928 - val_recall: 0.7483
# Epoch 94/100
# 92/92 [==============================] - 62s 672ms/step - loss: 0.2810 - accuracy: 0.9017 - precision: 0.9133 - recall: 0.8925 - val_loss: 0.6428 - val_accuracy: 0.7934 - val_precision: 0.8388 - val_recall: 0.7756
# Epoch 95/100
# 92/92 [==============================] - 62s 673ms/step - loss: 0.2407 - accuracy: 0.9064 - precision: 0.9204 - recall: 0.8969 - val_loss: 0.7218 - val_accuracy: 0.7798 - val_precision: 0.8107 - val_recall: 0.7497
# Epoch 96/100
# 92/92 [==============================] - 62s 672ms/step - loss: 0.2374 - accuracy: 0.9160 - precision: 0.9251 - recall: 0.9075 - val_loss: 0.6967 - val_accuracy: 0.7633 - val_precision: 0.7983 - val_recall: 0.7524
# Epoch 97/100
# 92/92 [==============================] - 62s 670ms/step - loss: 0.2619 - accuracy: 0.9040 - precision: 0.9159 - recall: 0.8928 - val_loss: 0.6995 - val_accuracy: 0.7688 - val_precision: 0.7988 - val_recall: 0.7442
# Epoch 98/100
# 92/92 [==============================] - 63s 688ms/step - loss: 0.2237 - accuracy: 0.9149 - precision: 0.9251 - recall: 0.9037 - val_loss: 0.6976 - val_accuracy: 0.7921 - val_precision: 0.8138 - val_recall: 0.7770
# Epoch 99/100
# 92/92 [==============================] - 63s 688ms/step - loss: 0.2471 - accuracy: 0.9098 - precision: 0.9174 - recall: 0.8989 - val_loss: 1.1345 - val_accuracy: 0.6785 - val_precision: 0.6991 - val_recall: 0.6580
# Epoch 100/100
# 92/92 [==============================] - 62s 676ms/step - loss: 0.2436 - accuracy: 0.9092 - precision: 0.9214 - recall: 0.9013 - val_loss: 1.0464 - val_accuracy: 0.6881 - val_precision: 0.7083 - val_recall: 0.6676

# %%
mpl.rcParams.update({'font.size': 10, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})

# %%
plt.figure(figsize=(20,5))
plt.plot(Result.history['accuracy'], label='accuracy')
plt.plot(Result.history['val_accuracy'], label='val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(list(range(1,100)))
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.figure(figsize=(20,5))
plt.plot(Result.history['loss'], label='train_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(list(range(1,100)))
plt.ylim([0, 2])
plt.legend(loc='lower right')

# %%
flower_gen_test.reset()
x_test, y_test = next(flower_gen_test)
for i in tqdm(range(int(len(flower_gen_test.labels)/b_size))):
  img, label = next(flower_gen_test)
  x_test = np.append(x_test, img, axis = 0)
  y_test = np.append(y_test, label, axis = 0)

print(x_test.shape,y_test.shape)
# Out:
# 100%|██████████| 22/22 [00:10<00:00,  2.19it/s]
# (731, 224, 224, 3) (731, 5)

# %%
#plt.figure(figsize=(10,5))
y_pred = model.predict(x_test)
#y_pred = model.predict(x_test).ravel()
#fpr, tpr, thresholds = roc_curve(y_test.ravel(), y_pred)
auc_keras = roc_auc_score(y_test,y_pred,multi_class='ovr')
print("ROC AUC score OVR:" + str(auc_keras))
#plt.title("ROC AUC score:" + str(auc_keras))
#plt.plot(y_test,y_pred, marker = ".")
auc_keras = roc_auc_score(y_test,y_pred,multi_class='ovo')
print("ROC AUC score OVO:" + str(auc_keras))
# Out:
# ROC AUC score OVR:0.9129161414692335
# ROC AUC score OVO:0.9129161414692335

# %% [markdown]
# The higher the AUC, the better performance of the model at distinguishing between the positives and negatives classes

# %% [markdown]
# **Final Scores**

# %% [markdown]
# Accuracy = $\frac{(TP+TN)}{(TP+FP+TN+FN)}$
#
# Precision = $\frac{TP}{(TP+FP)}$
#
# Recall =$\frac{TP}{(TP+FN)}$

# %%
y_pred = model.predict(x_test)
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_test, axis=1)

# %%
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
flower_labels = flower_gen_train.class_indices.keys()
print(flower_labels)
# Out:
# dict_keys(['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips'])

# %%
plot_confusion_matrix(y_test, y_pred, classes=np.r_[0,1,2,3,4], normalize=True, cmap=plt.cm.GnBu)
# Out:
# Normalized confusion matrix
# [[0.79365079 0.03968254 0.04761905 0.         0.11904762]
#  [0.08938547 0.7150838  0.07821229 0.01117318 0.10614525]
#  [0.0390625  0.0390625  0.5546875  0.0078125  0.359375  ]
#  [0.1294964  0.08633094 0.07194245 0.5971223  0.11510791]
#  [0.05031447 0.05031447 0.14465409 0.00628931 0.74842767]]

# %% [markdown]
# **Plot Evaluation**

# %%
model.save("07_model.h5")

# %%
def plot_example(X, y, y_pred=None):
# Create figure with 3 x 3 sub-plots.
  fig, axes = plt.subplots(3, 6)
  fig.set_size_inches(18,10)
  fig.subplots_adjust(hspace=0.3, wspace=0.3)
  X, y = X[:18, ..., 0], y[:18]
  for i, ax in enumerate(axes.flat):
    # Plot image.
    ax.imshow(X[i], alpha = 1)
    # Show true and predicted classes.
    if y_pred is None:
      xlabel = "True: {0}".format(y[i])
    else:
      xlabel = "True: {0}, Pred: {1}".format(y[i], y_pred[i])
    # Show the classes as the label on the x-axis.
    ax.set_xlabel(xlabel)
    # Remove ticks from the plot.
    ax.set_xticks([])
    ax.set_yticks([])
    # Ensure the plot is shown correctly with multiple plots in a single Notebook cell.
  plt.show()

# %%
model = tf.keras.models.load_model('07_model.h5')
#%matplotlib inline
# Make prediction
predictions = model.predict(x_test)
# retrieve prediction indices
pred_y = np.argmax(predictions, axis=1)
# Plot some examples with model predictions
plot_example(x_test, y_test, y_pred)
