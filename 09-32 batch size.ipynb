# %% [markdown]
# # Flower Classification
#
# **Exploracion de datos y Preprocesamiento**
#
# **Yalila Aljure Jimenez**
#
# email: yalila.aljure@udea.edu.co
#
# CC. 5288540

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.6.0'

# %%
import keras
keras.__version__
# Out:
# '2.6.0'

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import PIL
import pathlib
from mpl_toolkits.axes_grid1 import ImageGrid
from matplotlib import pyplot as plt
import random
import math 
from sklearn.metrics import roc_curve, auc, multilabel_confusion_matrix, plot_confusion_matrix
from keras.layers import Conv2D, Dropout, MaxPooling2D, BatchNormalization, Activation, Flatten, Dense, InputLayer, Input
from keras.models import Sequential, Model
import mlflow
import mlflow.keras

# %% [markdown]
# **LOAD DATA**

# %%
# !wget https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# Out:
# --2021-09-07 01:37:31--  https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.194.128, 173.194.195.128, 173.194.197.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.194.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 228813984 (218M) [application/x-compressed-tar]
# Saving to: ‘flower_photos.tgz’
#
# flower_photos.tgz   100%[===================>] 218.21M   169MB/s    in 1.3s
#
# 2021-09-07 01:37:32 (169 MB/s) - ‘flower_photos.tgz’ saved [228813984/228813984]

# %%
# Unzipping Data
# !gunzip flower_photos.tgz

# %% [markdown]
# **Plotting Images**

# %%
data_dir = pathlib.Path('flower_photos')
folder = list(data_dir.glob('*'))
images = list(data_dir.glob('*/*.jpg')) #list of all images (full path)

# %%
len(images) # Number of images
# Out:
# 3670

# %%
fig = plt.figure(figsize=(20, 20))
iterable = np.array(random.sample(range(1, 3670), 54)) # Choosing 54 random images
for i in range(54):
    plt.subplot(9, 6, i+1)
    j = iterable[i]
    plt.title(str(images[j]).split('/')[-1], fontsize=10) # file name and disply as title
    plt.imshow(PIL.Image.open(images[j])) # Displaying Image
    ax = plt.axis("off")

# %% [markdown]
# **Parameters**

# %%
image_size = 224 # Setting the size of the images
b_size = 32

# %% [markdown]
# **Imagen Preprocessing**
#
# Data Augmantation

# %% [markdown]
# Original source is not partitioned. The test set will be fixed at 20% of the entire dataset. The rest of the dataset will be used for training (0.8) and validation (0.2).

# %%
idg_flip = tf.keras.preprocessing.image.ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest',
    validation_split = 0.2
)

# %%
flower_gen_train = idg_flip.flow_from_directory(data_dir,
                                    target_size=(image_size, image_size),
                                    batch_size=b_size,
                                    subset='training',
                                    class_mode='categorical',
                                    shuffle=True,
                                    seed=123
                                    )
# Out:
# Found 2939 images belonging to 5 classes.

# %%
flower_gen_test = idg_flip.flow_from_directory(data_dir,
                                    target_size=(image_size, image_size),
                                    batch_size=b_size,
                                    subset='validation',
                                    class_mode='categorical',
                                    shuffle=True,
                                    seed=123
                                    )
# Out:
# Found 731 images belonging to 5 classes.

# %% [markdown]
# **VGGNet**

# %%
# Instanciate and empty model
model = Sequential()
# First Convolutional Layer
model.add(Conv2D(64, kernel_size=(3,3), activation='PReLU',padding='same',input_shape=(image_size,image_size,3))) # 2D Convolution layer, filters = 64
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(64, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 64
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(BatchNormalization()) 
# Second Convolutional Layer
model.add(Conv2D(128, kernel_size=(3,3), activation='PReLU', padding='same')) # 2D Convolution layer, filters = 128
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(128, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 128
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(BatchNormalization()) 
# Third Convolutional Layer
model.add(Conv2D(256, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 256
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(256, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 256
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(256, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 256
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(BatchNormalization()) 
# Fourth Convolutional Layer
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(BatchNormalization()) 
# Fith convolutional layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(BatchNormalization()) 
# 1st dense layer
model.add(Flatten()) 
model.add(Dense(4096))
# Dropout
model.add(Dropout(0.5)) 
model.add(Activation('PReLU'))
# 2nd Dense Layer
model.add(Dense(4096))
# Dropout
model.add(Dropout(0.5))
# Normalization
model.add(BatchNormalization()) 
model.add(Activation('PReLU'))
# Output softmax layer
model.add(Dense(5))
model.add(Activation('softmax'))

# %%
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy','Precision','Recall'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      3213056
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      839744
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 56, 56, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 128)       475264
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 128)       247936
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 256)       345344
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 256)         602624
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 256)         592384
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1, 1, 256)         1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 1, 512)         1180672
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1, 1, 512)         2048
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1, 1, 512)         2048
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# activation (Activation)      (None, 4096)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4096)              16384
# _________________________________________________________________
# activation_1 (Activation)    (None, 4096)              4096
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 20485
# _________________________________________________________________
# activation_2 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 38,232,133
# Trainable params: 38,220,997
# Non-trainable params: 11,136
# _________________________________________________________________

# %%
Result = model.fit(flower_gen_train, validation_data=flower_gen_test
                   , epochs=100, verbose=1, shuffle=True)
# Out:
# 2021/09/07 01:38:14 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '0501bd0465574003ab156e2ea6ec5907', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current keras workflow
# Epoch 1/100
# 92/92 [==============================] - 99s 724ms/step - loss: 1.4748 - accuracy: 0.4294 - precision: 0.5263 - recall: 0.2991 - val_loss: 1.6105 - val_accuracy: 0.1724 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# 92/92 [==============================] - 64s 697ms/step - loss: 1.2142 - accuracy: 0.5573 - precision: 0.6360 - recall: 0.4536 - val_loss: 1.6136 - val_accuracy: 0.1724 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/100
# 92/92 [==============================] - 65s 705ms/step - loss: 1.1237 - accuracy: 0.5886 - precision: 0.6625 - recall: 0.5002 - val_loss: 1.6166 - val_accuracy: 0.1751 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/100
# 92/92 [==============================] - 65s 703ms/step - loss: 1.0654 - accuracy: 0.6111 - precision: 0.6769 - recall: 0.5247 - val_loss: 1.6163 - val_accuracy: 0.2941 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/100
# 92/92 [==============================] - 65s 705ms/step - loss: 0.9607 - accuracy: 0.6380 - precision: 0.7146 - recall: 0.5563 - val_loss: 1.4444 - val_accuracy: 0.3953 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/100
# 92/92 [==============================] - 65s 705ms/step - loss: 0.9546 - accuracy: 0.6373 - precision: 0.7244 - recall: 0.5652 - val_loss: 1.2449 - val_accuracy: 0.5595 - val_precision: 0.9649 - val_recall: 0.0752
# Epoch 7/100
# 92/92 [==============================] - 65s 704ms/step - loss: 0.9361 - accuracy: 0.6468 - precision: 0.7135 - recall: 0.5669 - val_loss: 1.0198 - val_accuracy: 0.6334 - val_precision: 0.8577 - val_recall: 0.3133
# Epoch 8/100
# 92/92 [==============================] - 65s 702ms/step - loss: 0.8933 - accuracy: 0.6683 - precision: 0.7373 - recall: 0.5931 - val_loss: 1.3524 - val_accuracy: 0.5404 - val_precision: 0.6178 - val_recall: 0.4378
# Epoch 9/100
# 92/92 [==============================] - 65s 707ms/step - loss: 0.8920 - accuracy: 0.6635 - precision: 0.7254 - recall: 0.5869 - val_loss: 0.8660 - val_accuracy: 0.6580 - val_precision: 0.7749 - val_recall: 0.5321
# Epoch 10/100
# 92/92 [==============================] - 65s 708ms/step - loss: 0.8111 - accuracy: 0.6931 - precision: 0.7652 - recall: 0.6254 - val_loss: 1.0317 - val_accuracy: 0.6005 - val_precision: 0.6745 - val_recall: 0.5075
# Epoch 11/100
# 92/92 [==============================] - 65s 705ms/step - loss: 0.8195 - accuracy: 0.6808 - precision: 0.7518 - recall: 0.6070 - val_loss: 1.0416 - val_accuracy: 0.6635 - val_precision: 0.7250 - val_recall: 0.6060
# Epoch 12/100
# 92/92 [==============================] - 65s 703ms/step - loss: 0.7863 - accuracy: 0.7033 - precision: 0.7704 - recall: 0.6393 - val_loss: 1.3087 - val_accuracy: 0.5609 - val_precision: 0.6078 - val_recall: 0.4665
# Epoch 13/100
# 92/92 [==============================] - 65s 708ms/step - loss: 0.7912 - accuracy: 0.7016 - precision: 0.7696 - recall: 0.6342 - val_loss: 1.0347 - val_accuracy: 0.6525 - val_precision: 0.7008 - val_recall: 0.6088
# Epoch 14/100
# 92/92 [==============================] - 65s 701ms/step - loss: 0.7443 - accuracy: 0.7128 - precision: 0.7812 - recall: 0.6499 - val_loss: 1.1030 - val_accuracy: 0.6402 - val_precision: 0.7019 - val_recall: 0.5992
# Epoch 15/100
# 92/92 [==============================] - 65s 703ms/step - loss: 0.7749 - accuracy: 0.7121 - precision: 0.7749 - recall: 0.6431 - val_loss: 1.1271 - val_accuracy: 0.5896 - val_precision: 0.6777 - val_recall: 0.5034
# Epoch 16/100
# 92/92 [==============================] - 65s 704ms/step - loss: 0.7635 - accuracy: 0.7087 - precision: 0.7700 - recall: 0.6434 - val_loss: 1.0110 - val_accuracy: 0.6224 - val_precision: 0.6765 - val_recall: 0.5663
# Epoch 17/100
# 92/92 [==============================] - 65s 703ms/step - loss: 0.7676 - accuracy: 0.7135 - precision: 0.7823 - recall: 0.6506 - val_loss: 0.8012 - val_accuracy: 0.7031 - val_precision: 0.7882 - val_recall: 0.6211
# Epoch 18/100
# 92/92 [==============================] - 65s 706ms/step - loss: 0.6921 - accuracy: 0.7383 - precision: 0.7923 - recall: 0.6774 - val_loss: 1.0649 - val_accuracy: 0.6156 - val_precision: 0.6484 - val_recall: 0.5650
# Epoch 19/100
# 92/92 [==============================] - 65s 706ms/step - loss: 0.6878 - accuracy: 0.7404 - precision: 0.8035 - recall: 0.6819 - val_loss: 1.0226 - val_accuracy: 0.6648 - val_precision: 0.7037 - val_recall: 0.6238
# Epoch 20/100
# 92/92 [==============================] - 65s 704ms/step - loss: 0.6530 - accuracy: 0.7503 - precision: 0.8015 - recall: 0.6938 - val_loss: 0.8309 - val_accuracy: 0.6990 - val_precision: 0.7665 - val_recall: 0.6512
# Epoch 21/100
# 92/92 [==============================] - 65s 705ms/step - loss: 0.6655 - accuracy: 0.7496 - precision: 0.8076 - recall: 0.6968 - val_loss: 0.8739 - val_accuracy: 0.6840 - val_precision: 0.7572 - val_recall: 0.6101
# Epoch 22/100
# 92/92 [==============================] - 65s 705ms/step - loss: 0.6702 - accuracy: 0.7465 - precision: 0.8070 - recall: 0.6887 - val_loss: 0.8753 - val_accuracy: 0.6854 - val_precision: 0.7589 - val_recall: 0.6156
# Epoch 23/100
# 92/92 [==============================] - 65s 703ms/step - loss: 0.6375 - accuracy: 0.7550 - precision: 0.8150 - recall: 0.6968 - val_loss: 0.9801 - val_accuracy: 0.6635 - val_precision: 0.7188 - val_recall: 0.5978
# Epoch 24/100
# 92/92 [==============================] - 65s 701ms/step - loss: 0.6468 - accuracy: 0.7550 - precision: 0.8073 - recall: 0.6985 - val_loss: 0.9832 - val_accuracy: 0.6361 - val_precision: 0.7133 - val_recall: 0.5581
# Epoch 25/100
# 92/92 [==============================] - 65s 704ms/step - loss: 0.6311 - accuracy: 0.7537 - precision: 0.8085 - recall: 0.7040 - val_loss: 0.8450 - val_accuracy: 0.6963 - val_precision: 0.7630 - val_recall: 0.6430
# Epoch 26/100
# 92/92 [==============================] - 65s 705ms/step - loss: 0.6109 - accuracy: 0.7598 - precision: 0.8118 - recall: 0.7087 - val_loss: 0.8556 - val_accuracy: 0.7073 - val_precision: 0.7488 - val_recall: 0.6525
# Epoch 27/100
# 92/92 [==============================] - 65s 704ms/step - loss: 0.5863 - accuracy: 0.7785 - precision: 0.8291 - recall: 0.7295 - val_loss: 0.9222 - val_accuracy: 0.6443 - val_precision: 0.7100 - val_recall: 0.5828
# Epoch 28/100
# 92/92 [==============================] - 65s 705ms/step - loss: 0.6009 - accuracy: 0.7710 - precision: 0.8245 - recall: 0.7227 - val_loss: 1.2466 - val_accuracy: 0.5978 - val_precision: 0.6452 - val_recall: 0.5472
# Epoch 29/100
# 92/92 [==============================] - 65s 704ms/step - loss: 0.6074 - accuracy: 0.7761 - precision: 0.8231 - recall: 0.7234 - val_loss: 0.8862 - val_accuracy: 0.6813 - val_precision: 0.7516 - val_recall: 0.6334
# Epoch 30/100
# 92/92 [==============================] - 65s 704ms/step - loss: 0.5659 - accuracy: 0.7836 - precision: 0.8282 - recall: 0.7383 - val_loss: 0.8075 - val_accuracy: 0.6922 - val_precision: 0.7512 - val_recall: 0.6279
# Epoch 31/100
# 92/92 [==============================] - 65s 702ms/step - loss: 0.5779 - accuracy: 0.7924 - precision: 0.8385 - recall: 0.7438 - val_loss: 1.0803 - val_accuracy: 0.6621 - val_precision: 0.7017 - val_recall: 0.6306
# Epoch 32/100
# 92/92 [==============================] - 65s 703ms/step - loss: 0.5803 - accuracy: 0.7788 - precision: 0.8206 - recall: 0.7315 - val_loss: 0.7963 - val_accuracy: 0.7264 - val_precision: 0.7628 - val_recall: 0.6908
# Epoch 33/100
# 92/92 [==============================] - 66s 716ms/step - loss: 0.4240 - accuracy: 0.8438 - precision: 0.8736 - recall: 0.8255 - val_loss: 1.1512 - val_accuracy: 0.6854 - val_precision: 0.7278 - val_recall: 0.6512
# Epoch 59/100
# 92/92 [==============================] - 66s 716ms/step - loss: 0.3819 - accuracy: 0.8625 - precision: 0.8868 - recall: 0.8370 - val_loss: 0.7937 - val_accuracy: 0.7250 - val_precision: 0.7610 - val_recall: 0.6840
# Epoch 60/100
# 92/92 [==============================] - 66s 712ms/step - loss: 0.3953 - accuracy: 0.8557 - precision: 0.8818 - recall: 0.8299 - val_loss: 0.8619 - val_accuracy: 0.7209 - val_precision: 0.7706 - val_recall: 0.6895
# Epoch 61/100
# 92/92 [==============================] - 66s 711ms/step - loss: 0.3790 - accuracy: 0.8598 - precision: 0.8818 - recall: 0.8377 - val_loss: 0.7667 - val_accuracy: 0.7264 - val_precision: 0.7690 - val_recall: 0.6922
# Epoch 62/100
# 92/92 [==============================] - 66s 713ms/step - loss: 0.3902 - accuracy: 0.8639 - precision: 0.8838 - recall: 0.8357 - val_loss: 0.7867 - val_accuracy: 0.7305 - val_precision: 0.7663 - val_recall: 0.6908
# Epoch 63/100
# 92/92 [==============================] - 65s 707ms/step - loss: 0.3681 - accuracy: 0.8602 - precision: 0.8824 - recall: 0.8377 - val_loss: 0.7394 - val_accuracy: 0.7264 - val_precision: 0.7496 - val_recall: 0.6840
# Epoch 64/100
# 92/92 [==============================] - 65s 709ms/step - loss: 0.3822 - accuracy: 0.8564 - precision: 0.8768 - recall: 0.8329 - val_loss: 0.7498 - val_accuracy: 0.7606 - val_precision: 0.7821 - val_recall: 0.7415
# Epoch 65/100
# 92/92 [==============================] - 66s 714ms/step - loss: 0.3680 - accuracy: 0.8693 - precision: 0.8836 - recall: 0.8445 - val_loss: 0.7523 - val_accuracy: 0.7264 - val_precision: 0.7625 - val_recall: 0.6895
# Epoch 66/100
# 92/92 [==============================] - 65s 710ms/step - loss: 0.3599 - accuracy: 0.8680 - precision: 0.8831 - recall: 0.8459 - val_loss: 0.7664 - val_accuracy: 0.7196 - val_precision: 0.7467 - val_recall: 0.6977
# Epoch 67/100
# 92/92 [==============================] - 66s 717ms/step - loss: 0.3759 - accuracy: 0.8598 - precision: 0.8833 - recall: 0.8445 - val_loss: 0.6576 - val_accuracy: 0.7729 - val_precision: 0.8021 - val_recall: 0.7373
# Epoch 68/100
# 92/92 [==============================] - 66s 720ms/step - loss: 0.3324 - accuracy: 0.8755 - precision: 0.8925 - recall: 0.8561 - val_loss: 0.7920 - val_accuracy: 0.7428 - val_precision: 0.7686 - val_recall: 0.7223
# Epoch 69/100
# 92/92 [==============================] - 66s 721ms/step - loss: 0.3316 - accuracy: 0.8758 - precision: 0.8928 - recall: 0.8588 - val_loss: 0.6744 - val_accuracy: 0.7798 - val_precision: 0.8126 - val_recall: 0.7592
# Epoch 70/100
# Epoch 83/100
# 92/92 [==============================] - 66s 718ms/step - loss: 0.2683 - accuracy: 0.8996 - precision: 0.9126 - recall: 0.8884 - val_loss: 0.6822 - val_accuracy: 0.7907 - val_precision: 0.7986 - val_recall: 0.7592
# Epoch 84/100
# 92/92 [==============================] - 66s 715ms/step - loss: 0.2798 - accuracy: 0.8928 - precision: 0.9048 - recall: 0.8796 - val_loss: 0.7354 - val_accuracy: 0.7661 - val_precision: 0.7991 - val_recall: 0.7401
# Epoch 85/100
# 92/92 [==============================] - 66s 712ms/step - loss: 0.2962 - accuracy: 0.8840 - precision: 0.9011 - recall: 0.8738 - val_loss: 0.7577 - val_accuracy: 0.7592 - val_precision: 0.7895 - val_recall: 0.7387
# Epoch 86/100
# 92/92 [==============================] - 66s 712ms/step - loss: 0.2750 - accuracy: 0.8972 - precision: 0.9104 - recall: 0.8853 - val_loss: 0.7605 - val_accuracy: 0.7606 - val_precision: 0.7898 - val_recall: 0.7401
# Epoch 87/100
# 92/92 [==============================] - 66s 712ms/step - loss: 0.2491 - accuracy: 0.9098 - precision: 0.9215 - recall: 0.9023 - val_loss: 0.7562 - val_accuracy: 0.7510 - val_precision: 0.7958 - val_recall: 0.7250
# Epoch 88/100
# 92/92 [==============================] - 65s 709ms/step - loss: 0.2787 - accuracy: 0.8955 - precision: 0.9090 - recall: 0.8840 - val_loss: 0.8615 - val_accuracy: 0.7319 - val_precision: 0.7478 - val_recall: 0.7100
# Epoch 89/100
# 92/92 [==============================] - 65s 708ms/step - loss: 0.2659 - accuracy: 0.9037 - precision: 0.9147 - recall: 0.8938 - val_loss: 0.6566 - val_accuracy: 0.7866 - val_precision: 0.8112 - val_recall: 0.7702
# Epoch 90/100
# 92/92 [==============================] - 65s 709ms/step - loss: 0.2912 - accuracy: 0.8908 - precision: 0.9031 - recall: 0.8755 - val_loss: 0.9846 - val_accuracy: 0.6854 - val_precision: 0.7056 - val_recall: 0.6689
# Epoch 91/100
# 92/92 [==============================] - 65s 705ms/step - loss: 0.2724 - accuracy: 0.9013 - precision: 0.9151 - recall: 0.8877 - val_loss: 0.8933 - val_accuracy: 0.7483 - val_precision: 0.7657 - val_recall: 0.7332
# Epoch 92/100
# 92/92 [==============================] - 65s 707ms/step - loss: 0.2722 - accuracy: 0.8976 - precision: 0.9074 - recall: 0.8840 - val_loss: 0.7221 - val_accuracy: 0.7633 - val_precision: 0.7962 - val_recall: 0.7428
# Epoch 93/100
# 92/92 [==============================] - 65s 707ms/step - loss: 0.2738 - accuracy: 0.9000 - precision: 0.9078 - recall: 0.8877 - val_loss: 0.8644 - val_accuracy: 0.7483 - val_precision: 0.7771 - val_recall: 0.7346
# Epoch 94/100
# 92/92 [==============================] - 65s 704ms/step - loss: 0.2563 - accuracy: 0.8976 - precision: 0.9088 - recall: 0.8887 - val_loss: 0.7320 - val_accuracy: 0.7674 - val_precision: 0.7911 - val_recall: 0.7565
# Epoch 95/100
# 92/92 [==============================] - 65s 706ms/step - loss: 0.2479 - accuracy: 0.9095 - precision: 0.9201 - recall: 0.8969 - val_loss: 0.7546 - val_accuracy: 0.7606 - val_precision: 0.7853 - val_recall: 0.7456
# Epoch 96/100
# 92/92 [==============================] - 65s 703ms/step - loss: 0.2294 - accuracy: 0.9129 - precision: 0.9212 - recall: 0.9034 - val_loss: 0.6735 - val_accuracy: 0.8057 - val_precision: 0.8258 - val_recall: 0.7784
# Epoch 97/100
# 92/92 [==============================] - 65s 703ms/step - loss: 0.2311 - accuracy: 0.9139 - precision: 0.9217 - recall: 0.9017 - val_loss: 0.8526 - val_accuracy: 0.7360 - val_precision: 0.7646 - val_recall: 0.7155
# Epoch 98/100
# 92/92 [==============================] - 65s 704ms/step - loss: 0.2295 - accuracy: 0.9098 - precision: 0.9192 - recall: 0.9013 - val_loss: 0.7729 - val_accuracy: 0.7551 - val_precision: 0.7644 - val_recall: 0.7278
# Epoch 99/100
# 92/92 [==============================] - 65s 704ms/step - loss: 0.2326 - accuracy: 0.9109 - precision: 0.9187 - recall: 0.8993 - val_loss: 0.8121 - val_accuracy: 0.7565 - val_precision: 0.7765 - val_recall: 0.7415
# Epoch 100/100
# 92/92 [==============================] - 65s 703ms/step - loss: 0.2483 - accuracy: 0.9129 - precision: 0.9189 - recall: 0.9054 - val_loss: 0.7027 - val_accuracy: 0.7975 - val_precision: 0.8103 - val_recall: 0.7770
# INFO:tensorflow:Assets written to: /tmp/tmph1gb6k5k/model/data/model/assets

# %%
mpl.rcParams.update({'font.size': 10, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})

# %%
plt.figure(figsize=(20,5))
plt.plot(Result.history['accuracy'], label='accuracy')
plt.plot(Result.history['val_accuracy'], label='val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(list(range(1,100)))
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.figure(figsize=(20,5))
plt.plot(Result.history['loss'], label='train_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(list(range(1,100)))
plt.ylim([0, 2])
plt.legend(loc='lower right')

# %% [markdown]
# **Plot Evaluation**

# %%
model.save("07_model.h5")

# %%
def plot_example(X, y, y_pred=None):
# Create figure with 3 x 3 sub-plots.
  fig, axes = plt.subplots(3, 6)
  fig.set_size_inches(18,10)
  fig.subplots_adjust(hspace=0.3, wspace=0.3)
  X, y = X[:18, ..., 0], y[:18]
  for i, ax in enumerate(axes.flat):
    # Plot image.
    ax.imshow(X[i], cmap = 'gray', alpha = 1)
    # Show true and predicted classes.
    if y_pred is None:
      xlabel = "True: {0}".format(y[i])
    else:
      xlabel = "True: {0}, Pred: {1}".format(y[i], y_pred[i])
    # Show the classes as the label on the x-axis.
    ax.set_xlabel(xlabel)
    # Remove ticks from the plot.
    ax.set_xticks([])
    ax.set_yticks([])
    # Ensure the plot is shown correctly with multiple plots in a single Notebook cell.
  plt.show()

# %%
model = tf.keras.models.load_model('07_model.h5')
#%matplotlib inline
# Make prediction
predictions = model.predict(x_test)
# retrieve prediction indices
pred_y = np.argmax(predictions, axis=1)
# Plot some examples with model predictions
plot_example(x_test, y_test, pred_y)
