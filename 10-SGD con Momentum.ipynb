# %% [markdown]
# # Flower Classification
#
# **Exploracion de datos y Preprocesamiento**
#
# **Yalila Aljure Jimenez**
#
# email: yalila.aljure@udea.edu.co
#
# CC. 5288540

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.6.0'

# %%
import keras
keras.__version__
# Out:
# '2.6.0'

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import PIL
import pathlib
from mpl_toolkits.axes_grid1 import ImageGrid
from matplotlib import pyplot as plt
import random
import math 
from sklearn.metrics import roc_curve, auc, multilabel_confusion_matrix, plot_confusion_matrix, roc_auc_score
from keras.layers import Conv2D, Dropout, MaxPooling2D, BatchNormalization, Activation, Flatten, Dense, InputLayer, Input
from keras.models import Sequential, Model
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

# %% [markdown]
# **LOAD DATA**

# %%
# !wget https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# Out:
# --2021-10-21 22:43:01--  https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.111.128, 108.177.121.128, 142.250.103.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.111.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 228813984 (218M) [application/x-compressed-tar]
# Saving to: ‘flower_photos.tgz’
#
# flower_photos.tgz   100%[===================>] 218.21M   165MB/s    in 1.3s
#
# 2021-10-21 22:43:02 (165 MB/s) - ‘flower_photos.tgz’ saved [228813984/228813984]

# %%
# Unzipping Data
# !gunzip flower_photos.tgz

# %%
# !tar -xvf flower_photos.tar

# %% [markdown]
# **Plotting Images**

# %%
data_dir = pathlib.Path('flower_photos')
folder = list(data_dir.glob('*'))
images = list(data_dir.glob('*/*.jpg')) #list of all images (full path)

# %%
len(images) # Number of images
# Out:
# 3670

# %%
fig = plt.figure(figsize=(20, 20))
iterable = np.array(random.sample(range(1, 3670), 54)) # Choosing 54 random images
for i in range(54):
    plt.subplot(9, 6, i+1)
    j = iterable[i]
    plt.title(str(images[j]).split('/')[-1], fontsize=10) # file name and disply as title
    plt.imshow(PIL.Image.open(images[j])) # Displaying Image
    ax = plt.axis("off")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **Parameters**

# %%
image_size = 224 # Setting the size of the images
b_size = 32

# %% [markdown]
# **Imagen Preprocessing**
#
# Data Augmantation

# %% [markdown]
# Original source is not partitioned. The test set will be fixed at 20% of the entire dataset. The rest of the dataset will be used for training (0.8) and validation (0.2).

# %%
idg_flip = tf.keras.preprocessing.image.ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest',
    validation_split = 0.2
)

# %%
flower_gen_train = idg_flip.flow_from_directory(data_dir,
                                    target_size=(image_size, image_size),
                                    batch_size=b_size,
                                    subset='training',
                                    class_mode='categorical',
                                    shuffle=True,
                                    seed=123
                                    )
# Out:
# Found 2939 images belonging to 5 classes.

# %%
flower_gen_test = idg_flip.flow_from_directory(data_dir,
                                    target_size=(image_size, image_size),
                                    batch_size=b_size,
                                    subset='validation',
                                    class_mode='categorical',
                                    shuffle=True,
                                    seed=123
                                    )
# Out:
# Found 731 images belonging to 5 classes.

# %% [markdown]
# **VGGNet**

# %%
# Instanciate and empty model
model = Sequential()
# First Convolutional Layer
model.add(Conv2D(64, kernel_size=(3,3), activation='PReLU',padding='same',input_shape=(image_size,image_size,3))) # 2D Convolution layer, filters = 64
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(64, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 64
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(BatchNormalization()) 
# Second Convolutional Layer
model.add(Conv2D(128, kernel_size=(3,3), activation='PReLU', padding='same')) # 2D Convolution layer, filters = 128
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(128, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 128
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(BatchNormalization()) 
# Third Convolutional Layer
model.add(Conv2D(256, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 256
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(256, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 256
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(Conv2D(256, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 256
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2))) # MaxPooling layer 
model.add(BatchNormalization()) 
# Fourth Convolutional Layer
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(BatchNormalization()) 
# Fith convolutional layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(Conv2D(512, kernel_size=(3,3), activation='PReLU',padding='same')) # 2D Convolution layer, filters = 512
model.add(MaxPooling2D(pool_size = (2,2), strides = (2,2),padding='same')) # MaxPooling layer 
model.add(BatchNormalization()) 
# 1st dense layer
model.add(Flatten()) 
model.add(Dense(4096))
# Dropout
model.add(Dropout(0.5)) 
model.add(Activation('PReLU'))
# 2nd Dense Layer
model.add(Dense(4096))
# Dropout
model.add(Dropout(0.5))
# Normalization
model.add(BatchNormalization()) 
model.add(Activation('PReLU'))
# Output softmax layer
model.add(Dense(5))
model.add(Activation('softmax'))

# %%
SGD = tf.keras.optimizers.SGD(
    learning_rate=0.01, momentum=0.9, nesterov=False, name='SGD'
)

# %%
model.compile(optimizer=SGD, loss='categorical_crossentropy', metrics=['accuracy','Precision','Recall'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      3213056
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 64)      839744
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 56, 56, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 128)       475264
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 128)       247936
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 256)       345344
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 256)         602624
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 256)         592384
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1, 1, 256)         1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 1, 512)         1180672
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1, 1, 512)         2048
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 1, 1, 512)         2360320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1, 1, 512)         2048
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# activation (Activation)      (None, 4096)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 4096)              16384
# _________________________________________________________________
# activation_1 (Activation)    (None, 4096)              4096
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 20485
# _________________________________________________________________
# activation_2 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 38,232,133
# Trainable params: 38,220,997
# Non-trainable params: 11,136
# _________________________________________________________________

# %%
Result = model.fit(flower_gen_train, validation_data=flower_gen_test
                   , epochs=100, verbose=1, shuffle=True)
# Out:
# Epoch 1/100
# 92/92 [==============================] - 98s 698ms/step - loss: 2.8184 - accuracy: 0.2365 - precision: 0.2529 - recall: 0.1347 - val_loss: 227.7316 - val_accuracy: 0.2175 - val_precision: 0.2178 - val_recall: 0.2175
# Epoch 2/100
# 92/92 [==============================] - 61s 667ms/step - loss: 2.9097 - accuracy: 0.2372 - precision: 0.2583 - recall: 0.1140 - val_loss: 21.1012 - val_accuracy: 0.2271 - val_precision: 0.2658 - val_recall: 0.1724
# Epoch 3/100
# 92/92 [==============================] - 62s 678ms/step - loss: 3.3023 - accuracy: 0.2215 - precision: 0.2161 - recall: 0.1181 - val_loss: 2.1536 - val_accuracy: 0.1655 - val_precision: 0.1627 - val_recall: 0.1491
# Epoch 4/100
# 92/92 [==============================] - 62s 677ms/step - loss: 3.4146 - accuracy: 0.2184 - precision: 0.2296 - recall: 0.1119 - val_loss: 1.6944 - val_accuracy: 0.2476 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/100
# 92/92 [==============================] - 63s 687ms/step - loss: 3.3915 - accuracy: 0.2178 - precision: 0.2180 - recall: 0.1113 - val_loss: 9.8821 - val_accuracy: 0.2202 - val_precision: 0.1975 - val_recall: 0.0424
# Epoch 6/100
# 92/92 [==============================] - 62s 674ms/step - loss: 3.8059 - accuracy: 0.2116 - precision: 0.2116 - recall: 0.1150 - val_loss: 4.6737 - val_accuracy: 0.1956 - val_precision: 0.1441 - val_recall: 0.0438
# Epoch 7/100
# 92/92 [==============================] - 61s 667ms/step - loss: 3.5190 - accuracy: 0.2106 - precision: 0.2079 - recall: 0.1034 - val_loss: 2.5020 - val_accuracy: 0.2503 - val_precision: 0.2302 - val_recall: 0.0397
# Epoch 8/100
# 92/92 [==============================] - 62s 672ms/step - loss: 3.5830 - accuracy: 0.2099 - precision: 0.2094 - recall: 0.0960 - val_loss: 1.7089 - val_accuracy: 0.1737 - val_precision: 0.1818 - val_recall: 0.0027
# Epoch 9/100
# 92/92 [==============================] - 63s 687ms/step - loss: 3.4763 - accuracy: 0.2096 - precision: 0.2099 - recall: 0.0922 - val_loss: 2.1435 - val_accuracy: 0.1819 - val_precision: 0.2444 - val_recall: 0.0301
# Epoch 10/100
# 92/92 [==============================] - 62s 670ms/step - loss: 3.1975 - accuracy: 0.2300 - precision: 0.2461 - recall: 0.1123 - val_loss: 1.6645 - val_accuracy: 0.2449 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11
# Epoch 36/100
# 92/92 [==============================] - 63s 688ms/step - loss: 1.8800 - accuracy: 0.3988 - precision: 0.4562 - recall: 0.2426 - val_loss: 1.8654 - val_accuracy: 0.3639 - val_precision: 0.4426 - val_recall: 0.2845
# Epoch 37/100
# 92/92 [==============================] - 63s 687ms/step - loss: 1.8480 - accuracy: 0.4148 - precision: 0.4616 - recall: 0.2535 - val_loss: 1.9824 - val_accuracy: 0.3639 - val_precision: 0.4880 - val_recall: 0.2230
# Epoch 38/100
# 92/92 [==============================] - 64s 695ms/step - loss: 1.8029 - accuracy: 0.4171 - precision: 0.4687 - recall: 0.2368 - val_loss: 2.7109 - val_accuracy: 0.3981 - val_precision: 0.4871 - val_recall: 0.1546
# Epoch 39/100
# 92/92 [==============================] - 64s 696ms/step - loss: 1.8138 - accuracy: 0.4039 - precision: 0.4873 - recall: 0.2351 - val_loss: 1.8718 - val_accuracy: 0.4049 - val_precision: 0.5300 - val_recall: 0.1450
# Epoch 40/100
# 92/92 [==============================] - 64s 697ms/step - loss: 1.7140 - accuracy: 0.4206 - precision: 0.4939 - recall: 0.2341 - val_loss: 1.8049 - val_accuracy: 0.4487 - val_precision: 0.4841 - val_recall: 0.1669
# Epoch 41/100
# 92/92 [==============================] - 64s 698ms/step - loss: 1.8050 - accuracy: 0.4202 - precision: 0.4592 - recall: 0.2242 - val_loss: 1.8870 - val_accuracy: 0.4131 - val_precision: 0.4892 - val_recall: 0.3105
# Epoch 42/100
# 92/92 [==============================] - 63s 687ms/step - loss: 1.8050 - accuracy: 0.4137 - precision: 0.4662 - recall: 0.2368 - val_loss: 3.8130 - val_accuracy: 0.4200 - val_precision: 0.4167 - val_recall: 0.1710
# Epoch 43/100
# 92/92 [==============================] - 63s 683ms/step - loss: 1.7488 - accuracy: 0.4154 - precision: 0.4936 - recall: 0.2368 - val_loss: 2.0026 - val_accuracy: 0.4200 - val_precision: 0.4216 - val_recall: 0.1067
# Epoch 44/100
# 92/92 [==============================] - 63s 687ms/step - loss: 1.8259 - accuracy: 0.4192 - precision: 0.4615 - recall: 0.2634 - val_loss: 1.5651 - val_accuracy: 0.3584 - val_precision: 0.3737 - val_recall: 0.0506
# Epoch 45/100
# 92/92 [==============================] - 63s 687ms/step - loss: 1.7291 - accuracy: 0.4209 - precision: 0.4698 - recall: 0.2409 - val_loss: 2.0195 - val_accuracy: 0.4022 - val_precision: 0.5401 - val_recall: 0.1012
# Epoch 46/100
# 92/92 [==============================] - 63s 685ms/step - loss: 1.7572 - accuracy: 0.4287 - precision: 0.4926 - recall: 0.2480 - val_loss: 1.6649 - val_accuracy: 0.3748 - val_precision: 0.5192 - val_recall: 0.2216
# Epoch 47/100
# 92/92 [==============================] - 64s 690ms/step - loss: 1.7098 - accuracy: 0.4246 - precision: 0.4807 - recall: 0.2375 - val_loss: 1.6276 - val_accuracy: 0.3680 - val_precision: 0.4276 - val_recall: 0.2627
# Epoch 48/100
# 92/92 [==============================] - 64s 692ms/step - loss: 1.6281 - accuracy: 0.4328 - precision: 0.4877 - recall: 0.2419 - val_loss: 1.7859 - val_accuracy: 0.4159 - val_precision: 0.5742 - val_recall: 0.2435
# Epoch 49/100
# 92/92 [==============================] - 64s 692ms/step - loss: 1
# Epoch 76/100
# 92/92 [==============================] - 63s 683ms/step - loss: 1.2978 - accuracy: 0.4821 - precision: 0.5531 - recall: 0.2943 - val_loss: 1.1787 - val_accuracy: 0.5062 - val_precision: 0.7006 - val_recall: 0.1505
# Epoch 77/100
# 92/92 [==============================] - 63s 685ms/step - loss: 1.2328 - accuracy: 0.4920 - precision: 0.5691 - recall: 0.2916 - val_loss: 1.2141 - val_accuracy: 0.5007 - val_precision: 0.7965 - val_recall: 0.1231
# Epoch 78/100
# 92/92 [==============================] - 62s 676ms/step - loss: 1.3032 - accuracy: 0.4747 - precision: 0.5448 - recall: 0.2729 - val_loss: 1.3001 - val_accuracy: 0.4610 - val_precision: 0.6898 - val_recall: 0.2038
# Epoch 79/100
# 92/92 [==============================] - 62s 675ms/step - loss: 1.2339 - accuracy: 0.4825 - precision: 0.5772 - recall: 0.3117 - val_loss: 1.2060 - val_accuracy: 0.4884 - val_precision: 0.6073 - val_recall: 0.1819
# Epoch 80/100
# 92/92 [==============================] - 63s 679ms/step - loss: 1.2301 - accuracy: 0.4944 - precision: 0.5716 - recall: 0.2947 - val_loss: 1.2122 - val_accuracy: 0.4966 - val_precision: 0.6523 - val_recall: 0.2900
# Epoch 81/100
# 92/92 [==============================] - 63s 684ms/step - loss: 1.2177 - accuracy: 0.5036 - precision: 0.5775 - recall: 0.3106 - val_loss: 1.1606 - val_accuracy: 0.5007 - val_precision: 0.6746 - val_recall: 0.1929
# Epoch 82/100
# 92/92 [==============================] - 63s 679ms/step - loss: 1.1990 - accuracy: 0.4917 - precision: 0.5676 - recall: 0.2930 - val_loss: 1.2757 - val_accuracy: 0.5048 - val_precision: 0.5743 - val_recall: 0.3119
# Epoch 83/100
# 92/92 [==============================] - 63s 680ms/step - loss: 1.1990 - accuracy: 0.4940 - precision: 0.5816 - recall: 0.3239 - val_loss: 1.1961 - val_accuracy: 0.5144 - val_precision: 0.7030 - val_recall: 0.2558
# Epoch 84/100
# 92/92 [==============================] - 63s 689ms/step - loss: 1.1690 - accuracy: 0.5080 - precision: 0.5931 - recall: 0.3045 - val_loss: 1.1563 - val_accuracy: 0.5294 - val_precision: 0.6827 - val_recall: 0.1943
# Epoch 85/100
# 92/92 [==============================] - 64s 692ms/step - loss: 1.1793 - accuracy: 0.4998 - precision: 0.5963 - recall: 0.3076 - val_loss: 1.5072 - val_accuracy: 0.4706 - val_precision: 0.5693 - val_recall: 0.2585
# Epoch 86/100
# 92/92 [==============================] - 64s 698ms/step - loss: 1.1757 - accuracy: 0.5005 - precision: 0.5833 - recall: 0.3015 - val_loss: 1.2006 - val_accuracy: 0.4747 - val_precision: 0.7852 - val_recall: 0.1450
# Epoch 87/100
# 92/92 [==============================] - 63s 678ms/step - loss: 1.1869 - accuracy: 0.5145 - precision: 0.6029 - recall: 0.3368 - val_loss: 1.3956 - val_accuracy: 0.4432 - val_precision: 0.4020 - val_recall: 0.1094
# Epoch 88/100
# 92/92 [==============================] - 62s 676ms/step - loss: 1.1712 - accuracy: 0.5226 - precision: 0.5979 - recall: 0.3491 - val_loss: 1.2612 - val_accuracy: 0.5062 - val_precision: 0.8706 - val_recall: 0.1012
# Epoch 89/100
# 92/92 [==============================] - 62s 675ms/step - loss: 1.1299 - accuracy: 0.5305 - precision: 0.6382 - recall: 0.3464 - val_loss: 1.2415 - val_accuracy: 0.5705 - val_precision: 0.7733 - val_recall: 0.1819
# Epoch 90/100
# 92/92 [==============================] - 63s 679ms/step - loss: 1.1809 - accuracy: 0.5077 - precision: 0.5866 - recall: 0.3215 - val_loss: 1.1677 - val_accuracy: 0.5226 - val_precision: 0.8070 - val_recall: 0.1259
# Epoch 91/100
# 92/92 [==============================] - 63s 685ms/step - loss: 1.1352 - accuracy: 0.5257 - precision: 0.6308 - recall: 0.3488 - val_loss: 1.2450 - val_accuracy: 0.5335 - val_precision: 0.7573 - val_recall: 0.1067
# Epoch 92/100
# 92/92 [==============================] - 64s 692ms/step - loss: 1.1366 - accuracy: 0.5325 - precision: 0.6262 - recall: 0.3613 - val_loss: 1.2116 - val_accuracy: 0.5308 - val_precision: 0.7579 - val_recall: 0.1970
# Epoch 93/100
# 92/92 [==============================] - 64s 690ms/step - loss: 1.1110 - accuracy: 0.5362 - precision: 0.6158 - recall: 0.3828 - val_loss: 1.2624 - val_accuracy: 0.4911 - val_precision: 0.8129 - val_recall: 0.1546
# Epoch 94/100
# 92/92 [==============================] - 63s 686ms/step - loss: 1.1162 - accuracy: 0.5529 - precision: 0.6345 - recall: 0.3981 - val_loss: 1.2304 - val_accuracy: 0.5021 - val_precision: 0.6751 - val_recall: 0.3297
# Epoch 95/100
# 92/92 [==============================] - 63s 682ms/step - loss: 1.0792 - accuracy: 0.5652 - precision: 0.6438 - recall: 0.4175 - val_loss: 1.1431 - val_accuracy: 0.5568 - val_precision: 0.8210 - val_recall: 0.1819
# Epoch 96/100
# 92/92 [==============================] - 63s 683ms/step - loss: 1.0815 - accuracy: 0.5808 - precision: 0.6508 - recall: 0.4223 - val_loss: 1.1516 - val_accuracy: 0.5226 - val_precision: 0.7926 - val_recall: 0.2038
# Epoch 97/100
# 92/92 [==============================] - 63s 688ms/step - loss: 1.1013 - accuracy: 0.5740 - precision: 0.6295 - recall: 0.4250 - val_loss: 1.4638 - val_accuracy: 0.4172 - val_precision: 0.5812 - val_recall: 0.1860
# Epoch 98/100
# 92/92 [==============================] - 63s 688ms/step - loss: 1.0730 - accuracy: 0.5873 - precision: 0.6464 - recall: 0.4311 - val_loss: 1.1754 - val_accuracy: 0.5116 - val_precision: 0.6194 - val_recall: 0.2093
# Epoch 99/100
# 92/92 [==============================] - 64s 691ms/step - loss: 1.0445 - accuracy: 0.5886 - precision: 0.6593 - recall: 0.4590 - val_loss: 1.1445 - val_accuracy: 0.4979 - val_precision: 0.8525 - val_recall: 0.1423
# Epoch 100/100
# 92/92 [==============================] - 62s 678ms/step - loss: 1.0364 - accuracy: 0.5982 - precision: 0.6672 - recall: 0.4685 - val_loss: 1.0563 - val_accuracy: 0.5622 - val_precision: 0.7500 - val_recall: 0.3488

# %%
mpl.rcParams.update({'font.size': 10, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})

# %%
plt.figure(figsize=(20,5))
plt.plot(Result.history['accuracy'], label='accuracy')
plt.plot(Result.history['val_accuracy'], label='val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(list(range(1,100)))
plt.ylim([0, 1])
plt.legend(loc='lower right')

# %%
plt.figure(figsize=(20,5))
plt.plot(Result.history['loss'], label='train_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(list(range(1,100)))
plt.ylim([0, 2])
plt.legend(loc='lower right')

# %%
flower_gen_test.reset()
x_test, y_test = next(flower_gen_test)
for i in tqdm(range(int(len(flower_gen_test.labels)/b_size))):
  img, label = next(flower_gen_test)
  x_test = np.append(x_test, img, axis = 0)
  y_test = np.append(y_test, label, axis = 0)

print(x_test.shape,y_test.shape)
# Out:
# 100%|██████████| 22/22 [00:10<00:00,  2.17it/s]
# (731, 224, 224, 3) (731, 5)

# %%
#plt.figure(figsize=(10,5))
y_pred = model.predict(x_test)
#y_pred = model.predict(x_test).ravel()
#fpr, tpr, thresholds = roc_curve(y_test.ravel(), y_pred)
auc_keras = roc_auc_score(y_test,y_pred,multi_class='ovr')
print("ROC AUC score OVR:" + str(auc_keras))
#plt.title("ROC AUC score:" + str(auc_keras))
#plt.plot(y_test,y_pred, marker = ".")
auc_keras = roc_auc_score(y_test,y_pred,multi_class='ovo')
print("ROC AUC score OVO:" + str(auc_keras))
# Out:
# ROC AUC score OVR:0.8668457399441433
# ROC AUC score OVO:0.8668457399441433

# %% [markdown]
# The higher the AUC, the better performance of the model at distinguishing between the positives and negatives classes

# %% [markdown]
# **Final Scores**

# %% [markdown]
# Accuracy = $\frac{(TP+TN)}{(TP+FP+TN+FN)}$
#
# Precision = $\frac{TP}{(TP+FP)}$
#
# Recall =$\frac{TP}{(TP+FN)}$

# %%
y_pred = model.predict(x_test)
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(y_test, axis=1)

# %%
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
flower_labels = flower_gen_train.class_indices.keys()
print(flower_labels)
# Out:
# dict_keys(['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips'])

# %%
plot_confusion_matrix(y_test, y_pred, classes=np.r_[0,1,2,3,4], normalize=True)
# Out:
# Normalized confusion matrix
# [[0.4047619  0.52380952 0.05555556 0.00793651 0.00793651]
#  [0.08938547 0.84916201 0.         0.06145251 0.        ]
#  [0.21875    0.1015625  0.40625    0.015625   0.2578125 ]
#  [0.0647482  0.17985612 0.00719424 0.69064748 0.05755396]
#  [0.09433962 0.13207547 0.31446541 0.04402516 0.41509434]]

# %% [markdown]
# **Plot Evaluation**

# %%
model.save("07_model.h5")

# %%
def plot_example(X, y, y_pred=None):
# Create figure with 3 x 3 sub-plots.
  fig, axes = plt.subplots(3, 6)
  fig.set_size_inches(18,10)
  fig.subplots_adjust(hspace=0.3, wspace=0.3)
  X, y = X[:18, ..., 0], y[:18]
  for i, ax in enumerate(axes.flat):
    # Plot image.
    ax.imshow(X[i], alpha = 1)
    # Show true and predicted classes.
    if y_pred is None:
      xlabel = "True: {0}".format(y[i])
    else:
      xlabel = "True: {0}, Pred: {1}".format(y[i], y_pred[i])
    # Show the classes as the label on the x-axis.
    ax.set_xlabel(xlabel)
    # Remove ticks from the plot.
    ax.set_xticks([])
    ax.set_yticks([])
    # Ensure the plot is shown correctly with multiple plots in a single Notebook cell.
  plt.show()

# %%
model = tf.keras.models.load_model('07_model.h5')
#%matplotlib inline
# Make prediction
predictions = model.predict(x_test)
# retrieve prediction indices
pred_y = np.argmax(predictions, axis=1)
# Plot some examples with model predictions
plot_example(x_test, y_test, y_pred)
